# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 5: Summaries of Groups of Data
#
# So far you've learned how to select, reformat, manipulate, order, and summarize data from a single table in database.  In this lesson, you are going to learn how to summarize multiple subsets of your data in the same query.  The method for doing this is to include a "GROUP BY" clause in your SQL query.
#
#
#
# ## The GROUP BY clause
#
# The GROUP BY clause comes after the WHERE clause, but before ORDER BY or LIMIT:
#
# <img src="https://duke.box.com/shared/static/lc0yjfz1339q3mc04ne13m2q5tkzy3x7.jpg" width=400 alt="SELECT FROM WHERE ORDER BY" />
#
# The GROUP BY clause is easy to incorporate into your queries.  In fact, it might be a little too easy to incorporate into MySQL queries, because it can be used incorrectly in MySQL queries even when no error message is displayed.  As a consequence, I suggest you adopt a healthy dose of caution every time you use the GROUP BY clause.  By the end of this lesson, you will understand why.  When used correctly, though, GROUP BY is one of the most useful and efficient parts of an SQL query, and once you are comfortable using it, you will use it very frequently.
#
# **To get started, load the SQL library and the Dognition database, and set the dognition database as the default:**

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/dognitiondb
# %sql USE dognitiondb
# Out:
# 0 rows affected.
# []

# %% [markdown]
# Let's return to a question from MySQL Exercise 4.  How would you query the average rating for each of the 40 tests in the Reviews table? As we discussed, one very inefficient method to do that would be to write 40 separate queries with each one having a different test name in the WHERE conditional clause.  Then you could copy or transcribe the results from all 40 queries into one place.  But that wouldn't be very pleasant.  Here's how you could do the same thing using one query that has a GROUP BY clause:
#
# ```mySQL
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name
# ```
#
# This query will output the average rating for each test.  More technically, this query will instruct MySQL to average all the rows that have the same value in the test_name column.
#
# Notice that I included test_name in the SELECT statement.  As a strong rule of thumb, if you are grouping by a column, you should also include that column in the SELECT statement.  If you don't do this, you won't know to which group each row of your output corresponds.
#
# **To see what I mean, try the query above without test_name included in the SELECT statement:**

# %%
# %%sql
# SELECT AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name
# Out:
# 40 rows affected.
# [(Decimal('3.9206'),),
#  (Decimal('4.2857'),),
#  (Decimal('3.9272'),),
#  (Decimal('4.2153'),),
#  (Decimal('2.6741'),),
#  (Decimal('3.3514'),),
#  (Decimal('2.7647'),),
#  (Decimal('4.0000'),),
#  (Decimal('2.9372'),),
#  (Decimal('0.9632'),),
#  (Decimal('4.0093'),),
#  (Decimal('3.0965'),),
#  (Decimal('0.2174'),),
#  (Decimal('4.5223'),),
#  (Decimal('4.3066'),),
#  (Decimal('3.5584'),),
#  (Decimal('4.2623'),),
#  (Decimal('2.9841'),),
#  (Decimal('2.0303'),),
#  (Decimal('1.9805'),),
#  (Decimal('2.6173'),),
#  (Decimal('1.3693'),),
#  (Decimal('3.8492'),),
#  (Decimal('1.6625'),),
#  (Decimal('3.8519'),),
#  (Decimal('4.6667'),),
#  (Decimal('2.1818'),),
#  (Decimal('3.2778'),),
#  (Decimal('4.5111'),),
#  (Decimal('4.2857'),),
#  (Decimal('4.2857'),),
#  (Decimal('5.5676'),),
#  (Decimal('0.7909'),),
#  (Decimal('3.1293'),),
#  (Decimal('1.6737'),),
#  (Decimal('1.2020'),),
#  (Decimal('2.4594'),),
#  (Decimal('2.6570'),),
#  (Decimal('2.8477'),),
#  (Decimal('2.0035'),)]

# %% [markdown]
# You can form groups using derived values as well as original columns.  To illustrate this, let's address another question: how many tests were completed during each month of the year?
#
# To answer this question, we need to take advantage of another datetime function described in the website below:
#
# http://www.w3resource.com/mysql/date-and-time-functions/date-and-time-functions.php
#
# MONTH() will return a number representing the month of a date entry. To get the total number of tests completed each month, you could put the MONTH function into the GROUP BY clause, in this case through an alias:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month;
# ```
#
# You can also group by multiple columns or derived fields.  If we wanted to determine the total number of each type of test completed each month, you could include both "test_name" and the derived "Month" field in the GROUP BY clause, separated by a comma.
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month;
# ```
#
# MySQL allows you to use aliases in a GROUP BY clause, but some database systems do not.  If you are using a database system that does NOT accept aliases in GROUP BY clauses, you can still group by derived fields, but you have to duplicate the calculation for the derived field in the GROUP BY clause in addition to including the derived field in the SELECT clause:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, MONTH(created_at);
# ```
#
# Try the query once with test_name first in the GROUP BY list, and once with Month first in the GROUP BY list below.  Inspect the outputs:

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month
# Out:
# 480 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('1 vs 1 Game', 2, 28),
#  ('1 vs 1 Game', 3, 22),
#  ('1 vs 1 Game', 4, 12),
#  ('1 vs 1 Game', 5, 13),
#  ('1 vs 1 Game', 6, 18),
#  ('1 vs 1 Game', 7, 36),
#  ('1 vs 1 Game', 8, 17),
#  ('1 vs 1 Game', 9, 28),
#  ('1 vs 1 Game', 10, 27),
#  ('1 vs 1 Game', 11, 15),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 1, 35),
#  ('3 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 3, 34),
#  ('3 vs 1 Game', 4, 16),
#  ('3 vs 1 Game', 5, 34),
#  ('3 vs 1 Game', 6, 42),
#  ('3 vs 1 Game', 7, 37),
#  ('3 vs 1 Game', 8, 23),
#  ('3 vs 1 Game', 9, 24),
#  ('3 vs 1 Game', 10, 28),
#  ('3 vs 1 Game', 11, 22),
#  ('3 vs 1 Game', 12, 45),
#  ('5 vs 1 Game', 1, 59),
#  ('5 vs 1 Game', 2, 54),
#  ('5 vs 1 Game', 3, 57),
#  ('5 vs 1 Game', 4, 29),
#  ('5 vs 1 Game', 5, 50),
#  ('5 vs 1 Game', 6, 61),
#  ('5 vs 1 Game', 7, 69),
#  ('5 vs 1 Game', 8, 38),
#  ('5 vs 1 Game', 9, 50),
#  ('5 vs 1 Game', 10, 54),
#  ('5 vs 1 Game', 11, 40),
#  ('5 vs 1 Game', 12, 59),
#  ('Arm Pointing', 1, 622),
#  ('Arm Pointing', 2, 498),
#  ('Arm Pointing', 3, 507),
#  ('Arm Pointing', 4, 381),
#  ('Arm Pointing', 5, 1149),
#  ('Arm Pointing', 6, 1424),
#  ('Arm Pointing', 7, 913),
#  ('Arm Pointing', 8, 779),
#  ('Arm Pointing', 9, 1243),
#  ('Arm Pointing', 10, 2535),
#  ('Arm Pointing', 11, 735),
#  ('Arm Pointing', 12, 666),
#  ('Cover Your Eyes', 1, 452),
#  ('Cover Your Eyes', 2, 373),
#  ('Cover Your Eyes', 3, 416),
#  ('Cover Your Eyes', 4, 291),
#  ('Cover Your Eyes', 5, 753),
#  ('Cover Your Eyes', 6, 767),
#  ('Cover Your Eyes', 7, 521),
#  ('Cover Your Eyes', 8, 408),
#  ('Cover Your Eyes', 9, 574),
#  ('Cover Your Eyes', 10, 1653),
#  ('Cover Your Eyes', 11, 595),
#  ('Cover Your Eyes', 12, 447),
#  ('Delayed Cup Game', 1, 356),
#  ('Delayed Cup Game', 2, 319),
#  ('Delayed Cup Game', 3, 350),
#  ('Delayed Cup Game', 4, 256),
#  ('Delayed Cup Game', 5, 539),
#  ('Delayed Cup Game', 6, 525),
#  ('Delayed Cup Game', 7, 407),
#  ('Delayed Cup Game', 8, 355),
#  ('Delayed Cup Game', 9, 424),
#  ('Delayed Cup Game', 10, 1019),
#  ('Delayed Cup Game', 11, 422),
#  ('Delayed Cup Game', 12, 299),
#  ('Different Perspective', 1, 2),
#  ('Different Perspective', 2, 3),
#  ('Different Perspective', 3, 4),
#  ('Different Perspective', 4, 8),
#  ('Different Perspective', 5, 12),
#  ('Different Perspective', 6, 11),
#  ('Different Perspective', 7, 8),
#  ('Different Perspective', 8, 10),
#  ('Different Perspective', 9, 12),
#  ('Different Perspective', 10, 4),
#  ('Different Perspective', 11, 6),
#  ('Different Perspective', 12, 9),
#  ('Expression Game', 1, 6),
#  ('Expression Game', 2, 9),
#  ('Expression Game', 3, 12),
#  ('Expression Game', 4, 10),
#  ('Expression Game', 5, 9),
#  ('Expression Game', 6, 11),
#  ('Expression Game', 7, 12),
#  ('Expression Game', 8, 11),
#  ('Expression Game', 9, 17),
#  ('Expression Game', 10, 3),
#  ('Expression Game', 11, 11),
#  ('Expression Game', 12, 13),
#  ('Eye Contact Game', 1, 624),
#  ('Eye Contact Game', 2, 564),
#  ('Eye Contact Game', 3, 589),
#  ('Eye Contact Game', 4, 449),
#  ('Eye Contact Game', 5, 1408),
#  ('Eye Contact Game', 6, 1812),
#  ('Eye Contact Game', 7, 1194),
#  ('Eye Contact Game', 8, 1130),
#  ('Eye Contact Game', 9, 1674),
#  ('Eye Contact Game', 10, 3452),
#  ('Eye Contact Game', 11, 889),
#  ('Eye Contact Game', 12, 760),
#  ('Eye Contact Warm-up', 1, 707),
#  ('Eye Contact Warm-up', 2, 616),
#  ('Eye Contact Warm-up', 3, 616),
#  ('Eye Contact Warm-up', 4, 454),
#  ('Eye Contact Warm-up', 5, 1636),
#  ('Eye Contact Warm-up', 6, 2152),
#  ('Eye Contact Warm-up', 7, 1379),
#  ('Eye Contact Warm-up', 8, 1256),
#  ('Eye Contact Warm-up', 9, 1967),
#  ('Eye Contact Warm-up', 10, 3675),
#  ('Eye Contact Warm-up', 11, 941),
#  ('Eye Contact Warm-up', 12, 839),
#  ('Foot Pointing', 1, 506),
#  ('Foot Pointing', 2, 433),
#  ('Foot Pointing', 3, 477),
#  ('Foot Pointing', 4, 339),
#  ('Foot Pointing', 5, 926),
#  ('Foot Pointing', 6, 1125),
#  ('Foot Pointing', 7, 759),
#  ('Foot Pointing', 8, 653),
#  ('Foot Pointing', 9, 992),
#  ('Foot Pointing', 10, 2290),
#  ('Foot Pointing', 11, 685),
#  ('Foot Pointing', 12, 566),
#  ('Impossible Task Game', 1, 49),
#  ('Impossible Task Game', 2, 48),
#  ('Impossible Task Game', 3, 36),
#  ('Impossible Task Game', 4, 43),
#  ('Impossible Task Game', 5, 49),
#  ('Impossible Task Game', 6, 59),
#  ('Impossible Task Game', 7, 50),
#  ('Impossible Task Game', 8, 32),
#  ('Impossible Task Game', 9, 35),
#  ('Impossible Task Game', 10, 37),
#  ('Impossible Task Game', 11, 48),
#  ('Impossible Task Game', 12, 46),
#  ('Impossible Task Warm-up', 1, 51),
#  ('Impossible Task Warm-up', 2, 49),
#  ('Impossible Task Warm-up', 3, 37),
#  ('Impossible Task Warm-up', 4, 43),
#  ('Impossible Task Warm-up', 5, 49),
#  ('Impossible Task Warm-up', 6, 58),
#  ('Impossible Task Warm-up', 7, 51),
#  ('Impossible Task Warm-up', 8, 34),
#  ('Impossible Task Warm-up', 9, 36),
#  ('Impossible Task Warm-up', 10, 36),
#  ('Impossible Task Warm-up', 11, 49),
#  ('Impossible Task Warm-up', 12, 46),
#  ('Inferential Reasoning Game', 1, 410),
#  ('Inferential Reasoning Game', 2, 297),
#  ('Inferential Reasoning Game', 3, 335),
#  ('Inferential Reasoning Game', 4, 254),
#  ('Inferential Reasoning Game', 5, 533),
#  ('Inferential Reasoning Game', 6, 544),
#  ('Inferential Reasoning Game', 7, 432),
#  ('Inferential Reasoning Game', 8, 350),
#  ('Inferential Reasoning Game', 9, 398),
#  ('Inferential Reasoning Game', 10, 785),
#  ('Inferential Reasoning Game', 11, 362),
#  ('Inferential Reasoning Game', 12, 280),
#  ('Inferential Reasoning Warm-up', 1, 425),
#  ('Inferential Reasoning Warm-up', 2, 302),
#  ('Inferential Reasoning Warm-up', 3, 351),
#  ('Inferential Reasoning Warm-up', 4, 257),
#  ('Inferential Reasoning Warm-up', 5, 544),
#  ('Inferential Reasoning Warm-up', 6, 550),
#  ('Inferential Reasoning Warm-up', 7, 450),
#  ('Inferential Reasoning Warm-up', 8, 354),
#  ('Inferential Reasoning Warm-up', 9, 399),
#  ('Inferential Reasoning Warm-up', 10, 794),
#  ('Inferential Reasoning Warm-up', 11, 376),
#  ('Inferential Reasoning Warm-up', 12, 296),
#  ('Memory versus Pointing', 1, 464),
#  ('Memory versus Pointing', 2, 395),
#  ('Memory versus Pointing', 3, 381),
#  ('Memory versus Pointing', 4, 299),
#  ('Memory versus Pointing', 5, 711),
#  ('Memory versus Pointing', 6, 704),
#  ('Memory versus Pointing', 7, 511),
#  ('Memory versus Pointing', 8, 415),
#  ('Memory versus Pointing', 9, 574),
#  ('Memory versus Pointing', 10, 1218),
#  ('Memory versus Pointing', 11, 477),
#  ('Memory versus Pointing', 12, 376),
#  ('Memory versus Smell', 1, 465),
#  ('Memory versus Smell', 2, 374),
#  ('Memory versus Smell', 3, 382),
#  ('Memory versus Smell', 4, 280),
#  ('Memory versus Smell', 5, 667),
#  ('Memory versus Smell', 6, 666),
#  ('Memory versus Smell', 7, 491),
#  ('Memory versus Smell', 8, 402),
#  ('Memory versus Smell', 9, 529),
#  ('Memory versus Smell', 10, 1111),
#  ('Memory versus Smell', 11, 444),
#  ('Memory versus Smell', 12, 352),
#  ('Navigation Game', 1, 57),
#  ('Navigation Game', 2, 41),
#  ('Navigation Game', 3, 47),
#  ('Navigation Game', 4, 41),
#  ('Navigation Game', 5, 336),
#  ('Navigation Game', 6, 81),
#  ('Navigation Game', 7, 70),
#  ('Navigation Game', 8, 41),
#  ('Navigation Game', 9, 52),
#  ('Navigation Game', 10, 69),
#  ('Navigation Game', 11, 47),
#  ('Navigation Game', 12, 45),
#  ('Navigation Learning', 1, 59),
#  ('Navigation Learning', 2, 43),
#  ('Navigation Learning', 3, 47),
#  ('Navigation Learning', 4, 45),
#  ('Navigation Learning', 5, 444),
#  ('Navigation Learning', 6, 90),
#  ('Navigation Learning', 7, 74),
#  ('Navigation Learning', 8, 34),
#  ('Navigation Learning', 9, 54),
#  ('Navigation Learning', 10, 70),
#  ('Navigation Learning', 11, 47),
#  ('Navigation Learning', 12, 47),
#  ('Navigation Warm-up', 1, 62),
#  ('Navigation Warm-up', 2, 43),
#  ('Navigation Warm-up', 3, 50),
#  ('Navigation Warm-up', 4, 42),
#  ('Navigation Warm-up', 5, 625),
#  ('Navigation Warm-up', 6, 114),
#  ('Navigation Warm-up', 7, 88),
#  ('Navigation Warm-up', 8, 40),
#  ('Navigation Warm-up', 9, 58),
#  ('Navigation Warm-up', 10, 76),
#  ('Navigation Warm-up', 11, 52),
#  ('Navigation Warm-up', 12, 49),
#  ('Numerosity Warm-Up', 1, 36),
#  ('Numerosity Warm-Up', 2, 28),
#  ('Numerosity Warm-Up', 3, 35),
#  ('Numerosity Warm-Up', 4, 17),
#  ('Numerosity Warm-Up', 5, 37),
#  ('Numerosity Warm-Up', 6, 44),
#  ('Numerosity Warm-Up', 7, 37),
#  ('Numerosity Warm-Up', 8, 23),
#  ('Numerosity Warm-Up', 9, 24),
#  ('Numerosity Warm-Up', 10, 29),
#  ('Numerosity Warm-Up', 11, 26),
#  ('Numerosity Warm-Up', 12, 46),
#  ('One Cup Warm-up', 1, 476),
#  ('One Cup Warm-up', 2, 388),
#  ('One Cup Warm-up', 3, 388),
#  ('One Cup Warm-up', 4, 313),
#  ('One Cup Warm-up', 5, 757),
#  ('One Cup Warm-up', 6, 745),
#  ('One Cup Warm-up', 7, 536),
#  ('One Cup Warm-up', 8, 416),
#  ('One Cup Warm-up', 9, 602),
#  ('One Cup Warm-up', 10, 1272),
#  ('One Cup Warm-up', 11, 491),
#  ('One Cup Warm-up', 12, 401),
#  ('Physical Reasoning Game', 1, 317),
#  ('Physical Reasoning Game', 2, 252),
#  ('Physical Reasoning Game', 3, 321),
#  ('Physical Reasoning Game', 4, 224),
#  ('Physical Reasoning Game', 5, 430),
#  ('Physical Reasoning Game', 6, 424),
#  ('Physical Reasoning Game', 7, 360),
#  ('Physical Reasoning Game', 8, 316),
#  ('Physical Reasoning Game', 9, 309),
#  ('Physical Reasoning Game', 10, 711),
#  ('Physical Reasoning Game', 11, 341),
#  ('Physical Reasoning Game', 12, 250),
#  ('Physical Reasoning Warm-up', 1, 384),
#  ('Physical Reasoning Warm-up', 2, 290),
#  ('Physical Reasoning Warm-up', 3, 337),
#  ('Physical Reasoning Warm-up', 4, 247),
#  ('Physical Reasoning Warm-up', 5, 510),
#  ('Physical Reasoning Warm-up', 6, 504),
#  ('Physical Reasoning Warm-up', 7, 411),
#  ('Physical Reasoning Warm-up', 8, 347),
#  ('Physical Reasoning Warm-up', 9, 364),
#  ('Physical Reasoning Warm-up', 10, 742),
#  ('Physical Reasoning Warm-up', 11, 349),
#  ('Physical Reasoning Warm-up', 12, 276),
#  ('Self Control Game', 1, 8),
#  ('Self Control Game', 2, 8),
#  ('Self Control Game', 3, 11),
#  ('Self Control Game', 4, 9),
#  ('Self Control Game', 5, 9),
#  ('Self Control Game', 6, 11),
#  ('Self Control Game', 7, 14),
#  ('Self Control Game', 8, 13),
#  ('Self Control Game', 9, 19),
#  ('Self Control Game', 10, 9),
#  ('Self Control Game', 11, 15),
#  ('Self Control Game', 12, 6),
#  ('Shaker Game', 1, 2),
#  ('Shaker Game', 2, 9),
#  ('Shaker Game', 3, 8),
#  ('Shaker Game', 4, 4),
#  ('Shaker Game', 5, 10),
#  ('Shaker Game', 6, 7),
#  ('Shaker Game', 7, 5),
#  ('Shaker Game', 8, 6),
#  ('Shaker Game', 9, 12),
#  ('Shaker Game', 10, 10),
#  ('Shaker Game', 11, 3),
#  ('Shaker Game', 12, 1),
#  ('Shaker Warm-Up', 1, 2),
#  ('Shaker Warm-Up', 2, 11),
#  ('Shaker Warm-Up', 3, 8),
#  ('Shaker Warm-Up', 4, 4),
#  ('Shaker Warm-Up', 5, 10),
#  ('Shaker Warm-Up', 6, 7),
#  ('Shaker Warm-Up', 7, 5),
#  ('Shaker Warm-Up', 8, 6),
#  ('Shaker Warm-Up', 9, 13),
#  ('Shaker Warm-Up', 10, 11),
#  ('Shaker Warm-Up', 11, 3),
#  ('Shaker Warm-Up', 12, 1),
#  ('Shared Perspective', 1, 1),
#  ('Shared Perspective', 2, 3),
#  ('Shared Perspective', 3, 3),
#  ('Shared Perspective', 4, 8),
#  ('Shared Perspective', 5, 11),
#  ('Shared Perspective', 6, 11),
#  ('Shared Perspective', 7, 7),
#  ('Shared Perspective', 8, 10),
#  ('Shared Perspective', 9, 12),
#  ('Shared Perspective', 10, 4),
#  ('Shared Perspective', 11, 6),
#  ('Shared Perspective', 12, 7),
#  ('Slide', 1, 17),
#  ('Slide', 2, 12),
#  ('Slide', 3, 16),
#  ('Slide', 4, 11),
#  ('Slide', 5, 17),
#  ('Slide', 6, 10),
#  ('Slide', 7, 13),
#  ('Slide', 8, 6),
#  ('Slide', 9, 18),
#  ('Slide', 10, 7),
#  ('Slide', 11, 13),
#  ('Slide', 12, 7),
#  ('Smell Game', 1, 13),
#  ('Smell Game', 2, 18),
#  ('Smell Game', 3, 16),
#  ('Smell Game', 4, 6),
#  ('Smell Game', 5, 19),
#  ('Smell Game', 6, 9),
#  ('Smell Game', 7, 21),
#  ('Smell Game', 8, 10),
#  ('Smell Game', 9, 16),
#  ('Smell Game', 10, 15),
#  ('Smell Game', 11, 12),
#  ('Smell Game', 12, 13),
#  ('Stair Game', 1, 12),
#  ('Stair Game', 2, 8),
#  ('Stair Game', 3, 7),
#  ('Stair Game', 4, 4),
#  ('Stair Game', 5, 10),
#  ('Stair Game', 6, 7),
#  ('Stair Game', 7, 14),
#  ('Stair Game', 8, 15),
#  ('Stair Game', 9, 17),
#  ('Stair Game', 10, 7),
#  ('Stair Game', 11, 3),
#  ('Stair Game', 12, 8),
#  ('Switch', 1, 15),
#  ('Switch', 2, 12),
#  ('Switch', 3, 14),
#  ('Switch', 4, 11),
#  ('Switch', 5, 15),
#  ('Switch', 6, 11),
#  ('Switch', 7, 11),
#  ('Switch', 8, 10),
#  ('Switch', 9, 13),
#  ('Switch', 10, 9),
#  ('Switch', 11, 10),
#  ('Switch', 12, 6),
#  ('Treat Warm-up', 1, 626),
#  ('Treat Warm-up', 2, 495),
#  ('Treat Warm-up', 3, 515),
#  ('Treat Warm-up', 4, 393),
#  ('Treat Warm-up', 5, 1182),
#  ('Treat Warm-up', 6, 1444),
#  ('Treat Warm-up', 7, 951),
#  ('Treat Warm-up', 8, 791),
#  ('Treat Warm-up', 9, 1303),
#  ('Treat Warm-up', 10, 2626),
#  ('Treat Warm-up', 11, 744),
#  ('Treat Warm-up', 12, 667),
#  ('Turn Your Back', 1, 462),
#  ('Turn Your Back', 2, 372),
#  ('Turn Your Back', 3, 418),
#  ('Turn Your Back', 4, 298),
#  ('Turn Your Back', 5, 769),
#  ('Turn Your Back', 6, 778),
#  ('Turn Your Back', 7, 535),
#  ('Turn Your Back', 8, 418),
#  ('Turn Your Back', 9, 599),
#  ('Turn Your Back', 10, 1711),
#  ('Turn Your Back', 11, 601),
#  ('Turn Your Back', 12, 467),
#  ('Two Cup Warm-up', 1, 490),
#  ('Two Cup Warm-up', 2, 386),
#  ('Two Cup Warm-up', 3, 389),
#  ('Two Cup Warm-up', 4, 308),
#  ('Two Cup Warm-up', 5, 747),
#  ('Two Cup Warm-up', 6, 732),
#  ('Two Cup Warm-up', 7, 537),
#  ('Two Cup Warm-up', 8, 419),
#  ('Two Cup Warm-up', 9, 578),
#  ('Two Cup Warm-up', 10, 1234),
#  ('Two Cup Warm-up', 11, 482),
#  ('Two Cup Warm-up', 12, 379),
#  ('Warm-up', 1, 70),
#  ('Warm-up', 2, 77),
#  ('Warm-Up', 3, 79),
#  ('Warm-Up', 4, 54),
#  ('Warm-Up', 5, 71),
#  ('Warm-Up', 6, 64),
#  ('Warm-Up', 7, 101),
#  ('Warm-Up', 8, 64),
#  ('Warm-Up', 9, 103),
#  ('Warm-up', 10, 69),
#  ('Warm-Up', 11, 65),
#  ('Warm-up', 12, 56),
#  ('Watching', 1, 594),
#  ('Watching', 2, 443),
#  ('Watching', 3, 472),
#  ('Watching', 4, 322),
#  ('Watching', 5, 980),
#  ('Watching', 6, 1035),
#  ('Watching', 7, 679),
#  ('Watching', 8, 511),
#  ('Watching', 9, 809),
#  ('Watching', 10, 1797),
#  ('Watching', 11, 611),
#  ('Watching', 12, 555),
#  ('Watching - Part 2', 1, 445),
#  ('Watching - Part 2', 2, 372),
#  ('Watching - Part 2', 3, 406),
#  ('Watching - Part 2', 4, 282),
#  ('Watching - Part 2', 5, 734),
#  ('Watching - Part 2', 6, 747),
#  ('Watching - Part 2', 7, 504),
#  ('Watching - Part 2', 8, 405),
#  ('Watching - Part 2', 9, 568),
#  ('Watching - Part 2', 10, 1578),
#  ('Watching - Part 2', 11, 565),
#  ('Watching - Part 2', 12, 438),
#  ('Yawn Game', 1, 828),
#  ('Yawn Game', 2, 709),
#  ('Yawn Game', 3, 681),
#  ('Yawn Game', 4, 525),
#  ('Yawn Game', 5, 2065),
#  ('Yawn Game', 6, 2906),
#  ('Yawn Game', 7, 1775),
#  ('Yawn Game', 8, 1520),
#  ('Yawn Game', 9, 2563),
#  ('Yawn Game', 10, 4073),
#  ('Yawn Game', 11, 989),
#  ('Yawn Game', 12, 978),
#  ('Yawn Warm-up', 1, 834),
#  ('Yawn Warm-up', 2, 712),
#  ('Yawn Warm-up', 3, 698),
#  ('Yawn Warm-up', 4, 541),
#  ('Yawn Warm-up', 5, 2143),
#  ('Yawn Warm-up', 6, 3071),
#  ('Yawn Warm-up', 7, 1909),
#  ('Yawn Warm-up', 8, 1694),
#  ('Yawn Warm-up', 9, 2771),
#  ('Yawn Warm-up', 10, 4387),
#  ('Yawn Warm-up', 11, 1060),
#  ('Yawn Warm-up', 12, 1043)]

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month, test_name
# Out:
# 480 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('3 vs 1 Game', 1, 35),
#  ('5 vs 1 Game', 1, 59),
#  ('Arm Pointing', 1, 622),
#  ('Cover Your Eyes', 1, 452),
#  ('Delayed Cup Game', 1, 356),
#  ('Different Perspective', 1, 2),
#  ('Expression Game', 1, 6),
#  ('Eye Contact Game', 1, 624),
#  ('Eye Contact Warm-up', 1, 707),
#  ('Foot Pointing', 1, 506),
#  ('Impossible Task Game', 1, 49),
#  ('Impossible Task Warm-up', 1, 51),
#  ('Inferential Reasoning Game', 1, 410),
#  ('Inferential Reasoning Warm-up', 1, 425),
#  ('Memory versus Pointing', 1, 464),
#  ('Memory versus Smell', 1, 465),
#  ('Navigation Game', 1, 57),
#  ('Navigation Learning', 1, 59),
#  ('Navigation Warm-up', 1, 62),
#  ('Numerosity Warm-Up', 1, 36),
#  ('One Cup Warm-up', 1, 476),
#  ('Physical Reasoning Game', 1, 317),
#  ('Physical Reasoning Warm-up', 1, 384),
#  ('Self Control Game', 1, 8),
#  ('Shaker Game', 1, 2),
#  ('Shaker Warm-Up', 1, 2),
#  ('Shared Perspective', 1, 1),
#  ('Slide', 1, 17),
#  ('Smell Game', 1, 13),
#  ('Stair Game', 1, 12),
#  ('Switch', 1, 15),
#  ('Treat Warm-up', 1, 626),
#  ('Turn Your Back', 1, 462),
#  ('Two Cup Warm-up', 1, 490),
#  ('Warm-up', 1, 70),
#  ('Watching', 1, 594),
#  ('Watching - Part 2', 1, 445),
#  ('Yawn Game', 1, 828),
#  ('Yawn Warm-up', 1, 834),
#  ('1 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 2, 28),
#  ('5 vs 1 Game', 2, 54),
#  ('Arm Pointing', 2, 498),
#  ('Cover Your Eyes', 2, 373),
#  ('Delayed Cup Game', 2, 319),
#  ('Different Perspective', 2, 3),
#  ('Expression Game', 2, 9),
#  ('Eye Contact Game', 2, 564),
#  ('Eye Contact Warm-up', 2, 616),
#  ('Foot Pointing', 2, 433),
#  ('Impossible Task Game', 2, 48),
#  ('Impossible Task Warm-up', 2, 49),
#  ('Inferential Reasoning Game', 2, 297),
#  ('Inferential Reasoning Warm-up', 2, 302),
#  ('Memory versus Pointing', 2, 395),
#  ('Memory versus Smell', 2, 374),
#  ('Navigation Game', 2, 41),
#  ('Navigation Learning', 2, 43),
#  ('Navigation Warm-up', 2, 43),
#  ('Numerosity Warm-Up', 2, 28),
#  ('One Cup Warm-up', 2, 388),
#  ('Physical Reasoning Game', 2, 252),
#  ('Physical Reasoning Warm-up', 2, 290),
#  ('Self Control Game', 2, 8),
#  ('Shaker Game', 2, 9),
#  ('Shaker Warm-Up', 2, 11),
#  ('Shared Perspective', 2, 3),
#  ('Slide', 2, 12),
#  ('Smell Game', 2, 18),
#  ('Stair Game', 2, 8),
#  ('Switch', 2, 12),
#  ('Treat Warm-up', 2, 495),
#  ('Turn Your Back', 2, 372),
#  ('Two Cup Warm-up', 2, 386),
#  ('Warm-up', 2, 77),
#  ('Watching', 2, 443),
#  ('Watching - Part 2', 2, 372),
#  ('Yawn Game', 2, 709),
#  ('Yawn Warm-up', 2, 712),
#  ('1 vs 1 Game', 3, 22),
#  ('3 vs 1 Game', 3, 34),
#  ('5 vs 1 Game', 3, 57),
#  ('Arm Pointing', 3, 507),
#  ('Cover Your Eyes', 3, 416),
#  ('Delayed Cup Game', 3, 350),
#  ('Different Perspective', 3, 4),
#  ('Expression Game', 3, 12),
#  ('Eye Contact Game', 3, 589),
#  ('Eye Contact Warm-up', 3, 616),
#  ('Foot Pointing', 3, 477),
#  ('Impossible Task Game', 3, 36),
#  ('Impossible Task Warm-up', 3, 37),
#  ('Inferential Reasoning Game', 3, 335),
#  ('Inferential Reasoning Warm-up', 3, 351),
#  ('Memory versus Pointing', 3, 381),
#  ('Memory versus Smell', 3, 382),
#  ('Navigation Game', 3, 47),
#  ('Navigation Learning', 3, 47),
#  ('Navigation Warm-up', 3, 50),
#  ('Numerosity Warm-Up', 3, 35),
#  ('One Cup Warm-up', 3, 388),
#  ('Physical Reasoning Game', 3, 321),
#  ('Physical Reasoning Warm-up', 3, 337),
#  ('Self Control Game', 3, 11),
#  ('Shaker Game', 3, 8),
#  ('Shaker Warm-Up', 3, 8),
#  ('Shared Perspective', 3, 3),
#  ('Slide', 3, 16),
#  ('Smell Game', 3, 16),
#  ('Stair Game', 3, 7),
#  ('Switch', 3, 14),
#  ('Treat Warm-up', 3, 515),
#  ('Turn Your Back', 3, 418),
#  ('Two Cup Warm-up', 3, 389),
#  ('Warm-Up', 3, 79),
#  ('Watching', 3, 472),
#  ('Watching - Part 2', 3, 406),
#  ('Yawn Game', 3, 681),
#  ('Yawn Warm-up', 3, 698),
#  ('1 vs 1 Game', 4, 12),
#  ('3 vs 1 Game', 4, 16),
#  ('5 vs 1 Game', 4, 29),
#  ('Arm Pointing', 4, 381),
#  ('Cover Your Eyes', 4, 291),
#  ('Delayed Cup Game', 4, 256),
#  ('Different Perspective', 4, 8),
#  ('Expression Game', 4, 10),
#  ('Eye Contact Game', 4, 449),
#  ('Eye Contact Warm-up', 4, 454),
#  ('Foot Pointing', 4, 339),
#  ('Impossible Task Game', 4, 43),
#  ('Impossible Task Warm-up', 4, 43),
#  ('Inferential Reasoning Game', 4, 254),
#  ('Inferential Reasoning Warm-up', 4, 257),
#  ('Memory versus Pointing', 4, 299),
#  ('Memory versus Smell', 4, 280),
#  ('Navigation Game', 4, 41),
#  ('Navigation Learning', 4, 45),
#  ('Navigation Warm-up', 4, 42),
#  ('Numerosity Warm-Up', 4, 17),
#  ('One Cup Warm-up', 4, 313),
#  ('Physical Reasoning Game', 4, 224),
#  ('Physical Reasoning Warm-up', 4, 247),
#  ('Self Control Game', 4, 9),
#  ('Shaker Game', 4, 4),
#  ('Shaker Warm-Up', 4, 4),
#  ('Shared Perspective', 4, 8),
#  ('Slide', 4, 11),
#  ('Smell Game', 4, 6),
#  ('Stair Game', 4, 4),
#  ('Switch', 4, 11),
#  ('Treat Warm-up', 4, 393),
#  ('Turn Your Back', 4, 298),
#  ('Two Cup Warm-up', 4, 308),
#  ('Warm-Up', 4, 54),
#  ('Watching', 4, 322),
#  ('Watching - Part 2', 4, 282),
#  ('Yawn Game', 4, 525),
#  ('Yawn Warm-up', 4, 541),
#  ('1 vs 1 Game', 5, 13),
#  ('3 vs 1 Game', 5, 34),
#  ('5 vs 1 Game', 5, 50),
#  ('Arm Pointing', 5, 1149),
#  ('Cover Your Eyes', 5, 753),
#  ('Delayed Cup Game', 5, 539),
#  ('Different Perspective', 5, 12),
#  ('Expression Game', 5, 9),
#  ('Eye Contact Game', 5, 1408),
#  ('Eye Contact Warm-up', 5, 1636),
#  ('Foot Pointing', 5, 926),
#  ('Impossible Task Game', 5, 49),
#  ('Impossible Task Warm-up', 5, 49),
#  ('Inferential Reasoning Game', 5, 533),
#  ('Inferential Reasoning Warm-up', 5, 544),
#  ('Memory versus Pointing', 5, 711),
#  ('Memory versus Smell', 5, 667),
#  ('Navigation Game', 5, 336),
#  ('Navigation Learning', 5, 444),
#  ('Navigation Warm-up', 5, 625),
#  ('Numerosity Warm-Up', 5, 37),
#  ('One Cup Warm-up', 5, 757),
#  ('Physical Reasoning Game', 5, 430),
#  ('Physical Reasoning Warm-up', 5, 510),
#  ('Self Control Game', 5, 9),
#  ('Shaker Game', 5, 10),
#  ('Shaker Warm-Up', 5, 10),
#  ('Shared Perspective', 5, 11),
#  ('Slide', 5, 17),
#  ('Smell Game', 5, 19),
#  ('Stair Game', 5, 10),
#  ('Switch', 5, 15),
#  ('Treat Warm-up', 5, 1182),
#  ('Turn Your Back', 5, 769),
#  ('Two Cup Warm-up', 5, 747),
#  ('Warm-Up', 5, 71),
#  ('Watching', 5, 980),
#  ('Watching - Part 2', 5, 734),
#  ('Yawn Game', 5, 2065),
#  ('Yawn Warm-up', 5, 2143),
#  ('1 vs 1 Game', 6, 18),
#  ('3 vs 1 Game', 6, 42),
#  ('5 vs 1 Game', 6, 61),
#  ('Arm Pointing', 6, 1424),
#  ('Cover Your Eyes', 6, 767),
#  ('Delayed Cup Game', 6, 525),
#  ('Different Perspective', 6, 11),
#  ('Expression Game', 6, 11),
#  ('Eye Contact Game', 6, 1812),
#  ('Eye Contact Warm-up', 6, 2152),
#  ('Foot Pointing', 6, 1125),
#  ('Impossible Task Game', 6, 59),
#  ('Impossible Task Warm-up', 6, 58),
#  ('Inferential Reasoning Game', 6, 544),
#  ('Inferential Reasoning Warm-up', 6, 550),
#  ('Memory versus Pointing', 6, 704),
#  ('Memory versus Smell', 6, 666),
#  ('Navigation Game', 6, 81),
#  ('Navigation Learning', 6, 90),
#  ('Navigation Warm-up', 6, 114),
#  ('Numerosity Warm-Up', 6, 44),
#  ('One Cup Warm-up', 6, 745),
#  ('Physical Reasoning Game', 6, 424),
#  ('Physical Reasoning Warm-up', 6, 504),
#  ('Self Control Game', 6, 11),
#  ('Shaker Game', 6, 7),
#  ('Shaker Warm-Up', 6, 7),
#  ('Shared Perspective', 6, 11),
#  ('Slide', 6, 10),
#  ('Smell Game', 6, 9),
#  ('Stair Game', 6, 7),
#  ('Switch', 6, 11),
#  ('Treat Warm-up', 6, 1444),
#  ('Turn Your Back', 6, 778),
#  ('Two Cup Warm-up', 6, 732),
#  ('Warm-Up', 6, 64),
#  ('Watching', 6, 1035),
#  ('Watching - Part 2', 6, 747),
#  ('Yawn Game', 6, 2906),
#  ('Yawn Warm-up', 6, 3071),
#  ('1 vs 1 Game', 7, 36),
#  ('3 vs 1 Game', 7, 37),
#  ('5 vs 1 Game', 7, 69),
#  ('Arm Pointing', 7, 913),
#  ('Cover Your Eyes', 7, 521),
#  ('Delayed Cup Game', 7, 407),
#  ('Different Perspective', 7, 8),
#  ('Expression Game', 7, 12),
#  ('Eye Contact Game', 7, 1194),
#  ('Eye Contact Warm-up', 7, 1379),
#  ('Foot Pointing', 7, 759),
#  ('Impossible Task Game', 7, 50),
#  ('Impossible Task Warm-up', 7, 51),
#  ('Inferential Reasoning Game', 7, 432),
#  ('Inferential Reasoning Warm-up', 7, 450),
#  ('Memory versus Pointing', 7, 511),
#  ('Memory versus Smell', 7, 491),
#  ('Navigation Game', 7, 70),
#  ('Navigation Learning', 7, 74),
#  ('Navigation Warm-up', 7, 88),
#  ('Numerosity Warm-Up', 7, 37),
#  ('One Cup Warm-up', 7, 536),
#  ('Physical Reasoning Game', 7, 360),
#  ('Physical Reasoning Warm-up', 7, 411),
#  ('Self Control Game', 7, 14),
#  ('Shaker Game', 7, 5),
#  ('Shaker Warm-Up', 7, 5),
#  ('Shared Perspective', 7, 7),
#  ('Slide', 7, 13),
#  ('Smell Game', 7, 21),
#  ('Stair Game', 7, 14),
#  ('Switch', 7, 11),
#  ('Treat Warm-up', 7, 951),
#  ('Turn Your Back', 7, 535),
#  ('Two Cup Warm-up', 7, 537),
#  ('Warm-Up', 7, 101),
#  ('Watching', 7, 679),
#  ('Watching - Part 2', 7, 504),
#  ('Yawn Game', 7, 1775),
#  ('Yawn Warm-up', 7, 1909),
#  ('1 vs 1 Game', 8, 17),
#  ('3 vs 1 Game', 8, 23),
#  ('5 vs 1 Game', 8, 38),
#  ('Arm Pointing', 8, 779),
#  ('Cover Your Eyes', 8, 408),
#  ('Delayed Cup Game', 8, 355),
#  ('Different Perspective', 8, 10),
#  ('Expression Game', 8, 11),
#  ('Eye Contact Game', 8, 1130),
#  ('Eye Contact Warm-up', 8, 1256),
#  ('Foot Pointing', 8, 653),
#  ('Impossible Task Game', 8, 32),
#  ('Impossible Task Warm-up', 8, 34),
#  ('Inferential Reasoning Game', 8, 350),
#  ('Inferential Reasoning Warm-up', 8, 354),
#  ('Memory versus Pointing', 8, 415),
#  ('Memory versus Smell', 8, 402),
#  ('Navigation Game', 8, 41),
#  ('Navigation Learning', 8, 34),
#  ('Navigation Warm-up', 8, 40),
#  ('Numerosity Warm-Up', 8, 23),
#  ('One Cup Warm-up', 8, 416),
#  ('Physical Reasoning Game', 8, 316),
#  ('Physical Reasoning Warm-up', 8, 347),
#  ('Self Control Game', 8, 13),
#  ('Shaker Game', 8, 6),
#  ('Shaker Warm-Up', 8, 6),
#  ('Shared Perspective', 8, 10),
#  ('Slide', 8, 6),
#  ('Smell Game', 8, 10),
#  ('Stair Game', 8, 15),
#  ('Switch', 8, 10),
#  ('Treat Warm-up', 8, 791),
#  ('Turn Your Back', 8, 418),
#  ('Two Cup Warm-up', 8, 419),
#  ('Warm-Up', 8, 64),
#  ('Watching', 8, 511),
#  ('Watching - Part 2', 8, 405),
#  ('Yawn Game', 8, 1520),
#  ('Yawn Warm-up', 8, 1694),
#  ('1 vs 1 Game', 9, 28),
#  ('3 vs 1 Game', 9, 24),
#  ('5 vs 1 Game', 9, 50),
#  ('Arm Pointing', 9, 1243),
#  ('Cover Your Eyes', 9, 574),
#  ('Delayed Cup Game', 9, 424),
#  ('Different Perspective', 9, 12),
#  ('Expression Game', 9, 17),
#  ('Eye Contact Game', 9, 1674),
#  ('Eye Contact Warm-up', 9, 1967),
#  ('Foot Pointing', 9, 992),
#  ('Impossible Task Game', 9, 35),
#  ('Impossible Task Warm-up', 9, 36),
#  ('Inferential Reasoning Game', 9, 398),
#  ('Inferential Reasoning Warm-up', 9, 399),
#  ('Memory versus Pointing', 9, 574),
#  ('Memory versus Smell', 9, 529),
#  ('Navigation Game', 9, 52),
#  ('Navigation Learning', 9, 54),
#  ('Navigation Warm-up', 9, 58),
#  ('Numerosity Warm-Up', 9, 24),
#  ('One Cup Warm-up', 9, 602),
#  ('Physical Reasoning Game', 9, 309),
#  ('Physical Reasoning Warm-up', 9, 364),
#  ('Self Control Game', 9, 19),
#  ('Shaker Game', 9, 12),
#  ('Shaker Warm-Up', 9, 13),
#  ('Shared Perspective', 9, 12),
#  ('Slide', 9, 18),
#  ('Smell Game', 9, 16),
#  ('Stair Game', 9, 17),
#  ('Switch', 9, 13),
#  ('Treat Warm-up', 9, 1303),
#  ('Turn Your Back', 9, 599),
#  ('Two Cup Warm-up', 9, 578),
#  ('Warm-Up', 9, 103),
#  ('Watching', 9, 809),
#  ('Watching - Part 2', 9, 568),
#  ('Yawn Game', 9, 2563),
#  ('Yawn Warm-up', 9, 2771),
#  ('1 vs 1 Game', 10, 27),
#  ('3 vs 1 Game', 10, 28),
#  ('5 vs 1 Game', 10, 54),
#  ('Arm Pointing', 10, 2535),
#  ('Cover Your Eyes', 10, 1653),
#  ('Delayed Cup Game', 10, 1019),
#  ('Different Perspective', 10, 4),
#  ('Expression Game', 10, 3),
#  ('Eye Contact Game', 10, 3452),
#  ('Eye Contact Warm-up', 10, 3675),
#  ('Foot Pointing', 10, 2290),
#  ('Impossible Task Game', 10, 37),
#  ('Impossible Task Warm-up', 10, 36),
#  ('Inferential Reasoning Game', 10, 785),
#  ('Inferential Reasoning Warm-up', 10, 794),
#  ('Memory versus Pointing', 10, 1218),
#  ('Memory versus Smell', 10, 1111),
#  ('Navigation Game', 10, 69),
#  ('Navigation Learning', 10, 70),
#  ('Navigation Warm-up', 10, 76),
#  ('Numerosity Warm-Up', 10, 29),
#  ('One Cup Warm-up', 10, 1272),
#  ('Physical Reasoning Game', 10, 711),
#  ('Physical Reasoning Warm-up', 10, 742),
#  ('Self Control Game', 10, 9),
#  ('Shaker Game', 10, 10),
#  ('Shaker Warm-Up', 10, 11),
#  ('Shared Perspective', 10, 4),
#  ('Slide', 10, 7),
#  ('Smell Game', 10, 15),
#  ('Stair Game', 10, 7),
#  ('Switch', 10, 9),
#  ('Treat Warm-up', 10, 2626),
#  ('Turn Your Back', 10, 1711),
#  ('Two Cup Warm-up', 10, 1234),
#  ('Warm-up', 10, 69),
#  ('Watching', 10, 1797),
#  ('Watching - Part 2', 10, 1578),
#  ('Yawn Game', 10, 4073),
#  ('Yawn Warm-up', 10, 4387),
#  ('1 vs 1 Game', 11, 15),
#  ('3 vs 1 Game', 11, 22),
#  ('5 vs 1 Game', 11, 40),
#  ('Arm Pointing', 11, 735),
#  ('Cover Your Eyes', 11, 595),
#  ('Delayed Cup Game', 11, 422),
#  ('Different Perspective', 11, 6),
#  ('Expression Game', 11, 11),
#  ('Eye Contact Game', 11, 889),
#  ('Eye Contact Warm-up', 11, 941),
#  ('Foot Pointing', 11, 685),
#  ('Impossible Task Game', 11, 48),
#  ('Impossible Task Warm-up', 11, 49),
#  ('Inferential Reasoning Game', 11, 362),
#  ('Inferential Reasoning Warm-up', 11, 376),
#  ('Memory versus Pointing', 11, 477),
#  ('Memory versus Smell', 11, 444),
#  ('Navigation Game', 11, 47),
#  ('Navigation Learning', 11, 47),
#  ('Navigation Warm-up', 11, 52),
#  ('Numerosity Warm-Up', 11, 26),
#  ('One Cup Warm-up', 11, 491),
#  ('Physical Reasoning Game', 11, 341),
#  ('Physical Reasoning Warm-up', 11, 349),
#  ('Self Control Game', 11, 15),
#  ('Shaker Game', 11, 3),
#  ('Shaker Warm-Up', 11, 3),
#  ('Shared Perspective', 11, 6),
#  ('Slide', 11, 13),
#  ('Smell Game', 11, 12),
#  ('Stair Game', 11, 3),
#  ('Switch', 11, 10),
#  ('Treat Warm-up', 11, 744),
#  ('Turn Your Back', 11, 601),
#  ('Two Cup Warm-up', 11, 482),
#  ('Warm-Up', 11, 65),
#  ('Watching', 11, 611),
#  ('Watching - Part 2', 11, 565),
#  ('Yawn Game', 11, 989),
#  ('Yawn Warm-up', 11, 1060),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 12, 45),
#  ('5 vs 1 Game', 12, 59),
#  ('Arm Pointing', 12, 666),
#  ('Cover Your Eyes', 12, 447),
#  ('Delayed Cup Game', 12, 299),
#  ('Different Perspective', 12, 9),
#  ('Expression Game', 12, 13),
#  ('Eye Contact Game', 12, 760),
#  ('Eye Contact Warm-up', 12, 839),
#  ('Foot Pointing', 12, 566),
#  ('Impossible Task Game', 12, 46),
#  ('Impossible Task Warm-up', 12, 46),
#  ('Inferential Reasoning Game', 12, 280),
#  ('Inferential Reasoning Warm-up', 12, 296),
#  ('Memory versus Pointing', 12, 376),
#  ('Memory versus Smell', 12, 352),
#  ('Navigation Game', 12, 45),
#  ('Navigation Learning', 12, 47),
#  ('Navigation Warm-up', 12, 49),
#  ('Numerosity Warm-Up', 12, 46),
#  ('One Cup Warm-up', 12, 401),
#  ('Physical Reasoning Game', 12, 250),
#  ('Physical Reasoning Warm-up', 12, 276),
#  ('Self Control Game', 12, 6),
#  ('Shaker Game', 12, 1),
#  ('Shaker Warm-Up', 12, 1),
#  ('Shared Perspective', 12, 7),
#  ('Slide', 12, 7),
#  ('Smell Game', 12, 13),
#  ('Stair Game', 12, 8),
#  ('Switch', 12, 6),
#  ('Treat Warm-up', 12, 667),
#  ('Turn Your Back', 12, 467),
#  ('Two Cup Warm-up', 12, 379),
#  ('Warm-up', 12, 56),
#  ('Watching', 12, 555),
#  ('Watching - Part 2', 12, 438),
#  ('Yawn Game', 12, 978),
#  ('Yawn Warm-up', 12, 1043)]

# %% [markdown]
# Notice that in the first case, the first block of rows share the same test_name, but are broken up into separate months (for those of you who took the "Data Visualization and Communication with Tableau" course of this specialization, this is similar to what would happen if you put test_name first and created_at second on the rows or columns shelf in Tableau).
#
# In the second case, the first block of rows share the same month, but are broken up into separate tests  (this is similar to what would happen if you put created_at first and test_name second on the rows or columns shelf in Tableau).  If you were to visualize these outputs, they would look like the charts below.
#
# <img src="https://duke.box.com/shared/static/y6l3ldxg289brid5mmn886qweglt65qv.jpg" width=800 alt="ORDER" />
#
# Different database servers might default to ordering the outputs in a certain way, but you shouldn't rely on that being the case.  To ensure the output is ordered in a way you intend, add an ORDER BY clause to your grouped query using the syntax you already know and have practiced:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month
# ORDER BY test_name ASC, Month ASC;
# ```
#
# **Question 1: Output a table that calculates the number of distinct female and male dogs in each breed group of the Dogs table, sorted by the total number of dogs in descending order (the sex/breed_group pair with the greatest number of dogs should have 8466 unique Dog_Guids):**

# %%
# %%sql
# SELECT COUNT(DISTINCT dog_guid) AS number
# FROM dogs
# GROUP BY gender, breed_group
# ORDER BY number DESC
# Out:
# 18 rows affected.
# [(8466,),
#  (8367,),
#  (2584,),
#  (2262,),
#  (1736,),
#  (1704,),
#  (1473,),
#  (1145,),
#  (1098,),
#  (1075,),
#  (919,),
#  (919,),
#  (895,),
#  (794,),
#  (725,),
#  (614,),
#  (147,),
#  (127,)]

# %% [markdown]
# Some database servers, including MySQL, allow you to use numbers in place of field names in the GROUP BY or ORDER BY fields to reduce the overall length of the queries.  I tend to avoid this abbreviated method of writing queries because I find it challenging to troubleshoot when you are writing complicated queries with many fields, but it does allow you to write queries faster.  To use this method, assign each field in your SELECT statement a number acording to the order the field appears in the SELECT statement.  In the following statement:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# ```
#
# test_name would be #1, Month would be #2, and Num_Completed_Tests would be #3.  You could then rewrite the query above to read:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY 1, 2
# ORDER BY 1 ASC, 2 ASC;
# ```
#
# **Question 2: Revise the query your wrote in Question 1 so that it uses only numbers in the GROUP BY and ORDER BY fields.**

# %%
# %%sql
# SELECT gender, breed_group, COUNT(DISTINCT dog_guid) AS number
# FROM dogs
# GROUP BY 1, 2
# ORDER BY 3 DESC
# Out:
# 18 rows affected.
# [('male', None, 8466),
#  ('female', None, 8367),
#  ('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075),
#  ('female', 'Non-Sporting', 919),
#  ('male', 'Terrier', 919),
#  ('female', 'Working', 895),
#  ('female', 'Terrier', 794),
#  ('male', 'Hound', 725),
#  ('female', 'Hound', 614),
#  ('male', '', 147),
#  ('female', '', 127)]

# %% [markdown]
# ## The HAVING clause
#
# Just like you can query subsets of rows using the WHERE clause, you can query subsets of aggregated groups using the HAVING clause.  However, wheras the expression that follows a WHERE clause has to be applicable to each row of data in a column, the expression that follows a HAVING clause has to be applicable or computable using a group of data.
#
# If you wanted to examine the number of tests completed only during the winter holiday months of November and December, you would need to use a WHERE clause, because the month a test was completed in is recorded in each row.  Your query might look like this:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# ORDER BY 3 DESC;
# ```
# If you then wanted to output only the test-month pairs that had at least 20 records in them, you would add a HAVING clause, because the stipulation of at least 20 records only makes sense and is only computable at the aggregated group level:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# HAVING COUNT(created_at)>=20
# ORDER BY 3 DESC;
# ```
#
# **Question 3: Revise the query your wrote in Question 2 so that it (1) excludes the NULL and empty string entries in the breed_group field, and (2) excludes any groups that don't have at least 1,000 distinct Dog_Guids in them.  Your result should contain 8 rows.  (HINT: sometimes empty strings are registered as non-NULL values.  You might want to include the following line somewhere in your query to exclude these values as well):**
#
# ```mySQL
# breed_group!=""
# ```

# %%
# %%sql
# SELECT gender, breed_group, COUNT(DISTINCT dog_guid) AS number
# FROM dogs
# WHERE breed_group IS NOT NULL AND breed_group != ""
# GROUP BY 1, 2
# HAVING COUNT(DISTINCT dog_guid) >= 1000
# ORDER BY 3 DESC
# Out:
# 8 rows affected.
# [('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075)]

# %% [markdown]
# We will review several issues that can be tricky about using GROUP BY in your queries in the next lesson, but those issues will make more sense once you are sure you are comfortable with the basic functionality of the GROUP BY and HAVING clauses.
#
#
#
# ## Practice incorporating GROUP BY and HAVING into your own queries.
#
# **Question 4: Write a query that outputs the average number of tests completed and average mean inter-test-interval for every breed type, sorted by the average number of completed tests in descending order (popular hybrid should be the first row in your output).**

# %%
# %%sql
# SELECT breed, AVG(total_tests_completed) AS "Avg # of tests completed", AVG(mean_iti_days) AS "Avg mean iti"
# FROM dogs
# GROUP BY breed
# ORDER BY 2 DESC
# Out:
# 2006 rows affected.
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/default.py:470: Warning: (1292, "Truncated incorrect DOUBLE value: 'NaN'")
#   cursor.execute(statement, parameters)
# [('Golden Retriever-Brittany Mix', 43.0, 8.1217664242),
#  ('Golden Retriever-Airedale Terrier Mix', 42.0, 6.2796454381),
#  ('Rhodesian Ridgeback-American Staffordshire Terrier Mix', 40.5, 6.31787820915),
#  ('Siberian Husky-German Shorthaired Pointer Mix', 35.0, 14.620966095),
#  ('Portuguese Pointer', 34.0, 9.1572681678),
#  ('German Shepherd Dog-Gordon Setter Mix', 32.0, 5.5911271655),
#  ('Danish-Swedish Farmdog-Czechoslovakian Vlcak Mix', 31.0, 0.60351041667),
#  ('Australian Shepherd-Bloodhound Mix', 31.0, 3.9071863426),
#  ('-Collie Mix', 30.0, 2.8888533685),
#  ('German Shepherd Dog-American Eskimo Dog Mix', 30.0, 3.4515766044511498),
#  ('Schapendoes', 30.0, 12.380708014),
#  ('American Staffordshire Terrier-Australian Shepherd Mix', 28.0, 3.9638708848),
#  ('Tosa', 28.0, 3.7151513203),
#  ('Russell Terrier-Japanese Chin Mix', 28.0, 4.22708762),
#  ('Chihuahua-American Staffordshire Terrier Mix', 27.0, 7.8478303063),
#  ('Border Collie-Great Dane Mix', 26.5, 4.27937917955),
#  ('Australian Cattle Dog-Curly-Coated Retriever Mix', 26.0, 3.0393615741),
#  ('American Eskimo Dog-Papillon Mix', 25.0, 2.8316165123),
#  ('Boston Terrier-Pug Mix', 25.0, 0.41735966435),
#  ('American Pit Bull Terrier-Bull Terrier Mix', 25.0, 16.001591917),
#  ('Cardigan Welsh Corgi-Beagle Mix', 25.0, 1.220895544),
#  ('Polish Lowland Sheepdog', 23.5, 9.1719640976875),
#  ('Ibizan Hound', 23.5, 7.00201010511),
#  ('American Pit Bull Terrier- Mix', 23.5, 15.52087363165),
#  ('Basenji-Manchester Terrier Mix', 23.0, 0.5104682239),
#  ('American Pit Bull Terrier-Australian Shepherd Mix', 23.0, 3.4532417929),
#  ('Golden Retriever-St. Bernard Mix', 23.0, 4.1943802609),
#  ('Belgian Malinois-Chinese Shar-Pei Mix', 23.0, 11.780907513),
#  ('American Eskimo Dog-Staffordshire Bull Terrier Mix', 23.0, 1.278141835),
#  ('Border Collie-Whippet Mix', 22.5, 1.0629301317),
#  ('Labrador Retriever-Basenji Mix', 22.0, 7.9455891755),
#  ('Brittany-Poodle Mix', 22.0, 8.8587891314),
#  ('Boston Terrier-Bulldog Mix', 22.0, 13.716718474),
#  ('Catahoula Leopard Dog-Rottweiler Mix', 22.0, 1.5526813272),
#  ('Greyhound-Pointer Mix', 22.0, 16.112988316),
#  ('Bluetick Coonhound', 21.0, 4.168194153129799),
#  ('English Cocker Spaniel-Cocker Spaniel Mix', 20.0, 0.63819627193),
#  ('Beagle-Cavalier King Charles Spaniel Mix', 20.0, 0.83874269006),
#  ('Canaan Dog- Mix', 20.0, 2.5251821394),
#  ('Labrador Retriever-Cane Corso Mix', 20.0, 0.018192007801),
#  ('Pembroke Welsh Corgi-Russell Terrier Mix', 20.0, 6.6352473197),
#  ('Labrador Retriever-Cardigan Welsh Corgi Mix', 20.0, 0.0049348196848),
#  ('Pug-Maltese Mix', 20.0, 1.2138450292),
#  ('Alaskan Malamute-Collie Mix', 20.0, 0.35759868421),
#  ('Beagle- Mix', 20.0, 0.49765655458),
#  ('Bearded Collie-Beagle Mix', 20.0, 12.240281433),
#  ('Dogue de Bordeaux-Boxer Mix', 20.0, 0.737582846),
#  ('-German Shepherd Dog Mix', 20.0, 9.6689814815),
#  ('Afghan Hound-Golden Retriever Mix', 20.0, 0.4364254386),
#  ('Brittany-German Shorthaired Pointer Mix', 20.0, 0.43276864035),
#  ('American Eskimo Dog-Russell Terrier Mix', 20.0, 21.102933723),
#  ('Pekingese-Parson Russell Terrier Mix', 20.0, 0.014191033141),
#  ('Dachshund-Boston Terrier Mix', 20.0, 0.063846856723),
#  ('Redbone Coonhound-Bloodhound Mix', 20.0, 0.0064096003893),
#  ('Chinese Shar-Pei-Labrador Retriever Mix', 20.0, 0.48098745127),
#  ('Pomeranian-Basenji Mix', 20.0, 0.05885721248),
#  ('Portuguese Podengo Pequeno', 20.0, 0.19780519006),
#  ('Australian Shepherd-Shih Tzu Mix', 20.0, 0.23397112573),
#  ('American Pit Bull Terrier-Boston Terrier Mix', 20.0, 0.094918981483),
#  ('Doberman Pinscher-Greyhound Mix', 20.0, 6.3433857212),
#  ('Redbone Coonhound-Rhodesian Ridgeback Mix', 20.0, 0.077277046788),
#  ('Catahoula Leopard Dog-Plott Mix', 20.0, 0.078545321637),
#  ('Poodle-Japanese Chin Mix', 20.0, 12.08827059),
#  ('Great Pyrenees-Siberian Husky Mix', 20.0, 37.461845151),
#  ('Dachshund-Pomeranian Mix', 20.0, 14.674441399),
#  ('Poodle-Pomeranian Mix', 20.0, 0.24835709065),
#  ('Portuguese Podengo', 20.0, 0.66308235867),
#  ('Labrador Retriever-Flat-Coated Retriever Mix', 20.0, 0.086532041914),
#  ('Belgian Tervuren-Whippet Mix', 20.0, 0.26427814328),
#  ('Dogue de Bordeaux-Labrador Retriever Mix', 20.0, 0.045491593571),
#  ('Weimaraner-Bluetick Coonhound Mix', 20.0, 4.9569931774),
#  ('Jindo-German Shepherd Dog Mix', 20.0, 0.23014924464),
#  ('Dalmatian-American Pit Bull Terrier Mix', 20.0, 1.5868555068),
#  ('Pug-French Bulldog Mix', 20.0, 1.4924128899),
#  ('Bull Terrier-Staffordshire Bull Terrier Mix', 20.0, 0.0053587962972),
#  ('Basset Hound-Beagle Mix', 20.0, 7.6774890351),
#  ('Perro de Presa Canario', 20.0, 0.21083150585),
#  ('Boxer-Siberian Husky Mix', 20.0, 0.15824500487),
#  ('Irish Wolfhound-Great Dane Mix', 20.0, 1.0512621832),
#  ('Border Collie-Boxer Mix', 20.0, 0.46053362573),
#  ('Irish Setter-Poodle Mix', 20.0, 2.02459277532),
#  ('Bullmastiff-Chinese Shar-Pei Mix', 20.0, 0.16996893275),
#  ('Greyhound-Saluki Mix', 20.0, 0.054609527291),
#  ('Greyhound-Scottish Deerhound Mix', 20.0, 6.1592233187),
#  ('Bernese Mountain Dog-Border Collie Mix', 20.0, 0.89531310916),
#  ('Border Collie-Belgian Sheepdog Mix', 20.0, 0.0065777290454),
#  ('American Eskimo Dog-Australian Shepherd Mix', 20.0, 0.31412524367),
#  ('German Shepherd Dog-Shiba Inu Mix', 20.0, 0.26868664717),
#  ('Beagle-Chow Chow Mix', 20.0, 3.3147313597),
#  ('Beagle-Smooth Fox Terrier Mix', 20.0, 4.1648781676),
#  ('Airedale Terrier-German Shorthaired Pointer Mix', 20.0, 0.26880969785),
#  ('Miniature Schnauzer-Shih Tzu Mix', 20.0, 0.22639132553),
#  ('Rottweiler-Border Collie Mix', 20.0, 3.843079922),
#  ('English Setter-Border Collie Mix', 20.0, 27.835118177),
#  ('Yorkshire Terrier-Rat Terrier Mix', 20.0, 0.0038444200763),
#  ('Lhasa Apso-Bichon Frise Mix', 20.0, 1.6367422027),
#  ('Belgian Malinois-Chow Chow Mix', 20.0, 0.47114035088),
#  ('German Shepherd Dog-Pug Mix', 20.0, 1.8544688109),
#  ('Pug-Pekingese Mix', 20.0, 0.83532590156),
#  ('Australian Terrier-Lowchen Mix', 20.0, 0.10893274853),
#  ('Cairn Terrier-Pomeranian Mix', 20.0, 0.87942434211),
#  ('Australian Cattle Dog-Catahoula Leopard Dog Mix', 20.0, 0.0035118177398),
#  ('Belgian Malinois-German Shepherd Dog Mix', 20.0, 0.26031371832),
#  ('Affenpinscher-Brussels Griffon Mix', 20.0, 0.16213023879),
#  ('Australian Shepherd-Flat-Coated Retriever Mix', 20.0, 7.9997337963),
#  ('Giant Schnauzer-American Eskimo Dog Mix', 20.0, 0.21435733431),
#  ('Akita-Labrador Retriever Mix', 20.0, 0.29315241228),
#  ('American Staffordshire Terrier-Dogo Argentino Mix', 20.0, 0.10491106238),
#  ('Cairn Terrier-Airedale Terrier Mix', 20.0, 1.4724476121),
#  ('German Shepherd Dog-Keeshond Mix', 20.0, 0.1109225755353),
#  ('Border Terrier-Cairn Terrier Mix', 20.0, 0.46022356238),
#  ('Beagle-Shetland Sheepdog Mix', 20.0, 0.4744499269),
#  ('Whippet-Beagle Mix', 20.0, 0.10527534113),
#  ('Chinook-German Shepherd Dog Mix', 20.0, 0.24967531677),
#  ('Nova Scotia Duck Tolling Retriever-Chihuahua Mix', 20.0, 1.479201998),
#  ('Miniature Pinscher-Basenji Mix', 20.0, 0.36764985381),
#  ('Labrador Retriever-Bichon Frise Mix', 20.0, 0.36063901072),
#  ('Bullmastiff-Labrador Retriever Mix', 20.0, 2.9057364766),
#  ('Border Terrier-West Highland White Terrier Mix', 20.0, 0.3106792154),
#  ('Cavalier King Charles Spaniel-Pekingese Mix', 20.0, 0.33801047758),
#  ('Treeing Walker Coonhound-Parson Russell Terrier Mix', 20.0, 7.2692227096),
#  ('Parson Russell Terrier-Maltese Mix', 20.0, 0.32021990741),
#  ('Welsh Terrier-Miniature Schnauzer Mix', 20.0, 0.04324500487),
#  ('Papillon-Chihuahua Mix', 20.0, 0.078288864522),
#  ('Papillon-German Spitz Mix', 20.0, 0.095356359649),
#  ('Miniature Schnauzer-Labrador Retriever Mix', 20.0, 1.7097386696),
#  ('Labrador Retriever-Belgian Malinois Mix', 20.0, 0.31879446882),
#  ('Doberman Pinscher-Dalmatian Mix', 20.0, 0.27043311403),
#  ('Poodle-Bernese Mountain Dog Mix', 20.0, 10.801188475),
#  ('German Shepherd Dog-Bloodhound Mix', 20.0, 0.37913559942),
#  ('Beagle-Chinese Shar-Pei Mix', 20.0, 1.6511366959),
#  ('Flat-Coated Retriever-Irish Water Spaniel Mix', 20.0, 0.79957967837),
#  ('Australian Cattle Dog-Bearded Collie Mix', 20.0, 0.079224537035),
#  ('Border Collie-Borzoi Mix', 20.0, 1.5442172271),
#  ('Chihuahua-Boston Terrier Mix', 20.0, 1.1052655945),
#  ('German Shorthaired Pointer-German Longhaired Pointer Mix', 20.0, 3.423441155),
#  ('Miniature Schnauzer-Russell Terrier Mix', 20.0, 5.6898550195),
#  ('American Staffordshire Terrier-Treeing Walker Coonhound Mix', 20.0, 0.1594243421),
#  ('Redbone Coonhound-Australian Shepherd Mix', 20.0, 0.23064997564),
#  ('American Pit Bull Terrier-Dogue de Bordeaux Mix', 20.0, 0.27250243665),
#  ('Pembroke Welsh Corgi-Border Collie Mix', 20.0, 1.4742610867),
#  ('Brittany-Basset Hound Mix', 20.0, 4.7177528021),
#  ('Border Collie-Bull Terrier Mix', 20.0, 9.6258473441),
#  ('Siberian Husky-Mastiff Mix', 20.0, 0.27311342593),
#  ('Rottweiler-Greater Swiss Mountain Dog Mix', 20.0, 2.6249470029),
#  ('Pug-Poodle Mix', 20.0, 0.32626157408),
#  ('Havanese-Coton de Tulear Mix', 20.0, 2.5690692008),
#  ('Whippet-Rhodesian Ridgeback Mix', 20.0, 0.26635355751),
#  ('Pomeranian-Boston Terrier Mix', 20.0, 0.53086196393),
#  ('Pomeranian-Anatolian Shepherd Dog Mix', 20.0, 1.1626723928),
#  ('Jack Russell Terrier-Labrador Retriever Mix', 20.0, 0.21093384503),
#  ('Australian Cattle Dog-Redbone Coonhound Mix', 20.0, 0.68213572125),
#  ('Beagle-Greyhound Mix', 20.0, 8.9830123051),
#  ('Basenji-English Springer Spaniel Mix', 20.0, 0.58234039961),
#  ('American English Coonhound', 20.0, 0.7919371345),
#  ('Standard Poodle-Irish Setter Mix', 20.0, 0.16607029727),
#  ('American Hairless Terrier-Shetland Sheepdog Mix', 20.0, 0.0014906189048),
#  ('Beagle-Boston Terrier Mix', 20.0, 0.25473988791),
#  ('American Pit Bull Terrier-Border Collie Mix', 20.0, 0.32047149122),
#  ('Pug-Cocker Spaniel Mix', 20.0, 0.53071576511),
#  ('Cardigan Welsh Corgi-Catahoula Leopard Dog Mix', 20.0, 0.10122746102),
#  ('Chinese Shar-Pei-Cocker Spaniel Mix', 20.0, 0.24488913255),
#  ('Jack Russell Terrier-Cavalier King Charles Spaniel Mix', 20.0, 0.68649244639),
#  ('Wire Fox Terrier-Italian Greyhound Mix', 20.0, 0.68572307505),
#  ('Border Collie-Great Pyrenees Mix', 20.0, 0.20577729045),
#  ('Rat Terrier-Yorkshire Terrier Mix', 20.0, 1.1470827242),
#  ('Silky Terrier-Schipperke Mix', 20.0, 0.0033138401586),
#  ('Saluki-Greyhound Mix', 20.0, 0.63197855751),
#  ('Keeshond-German Shepherd Dog Mix', 20.0, 0.091948099416),
#  ('Dachshund-Staffordshire Bull Terrier Mix', 20.0, 0.003368055552),
#  ('Australian Cattle Dog-Treeing Walker Coonhound Mix', 20.0, 0.0041940789486),
#  ('Basset Hound-American Staffordshire Terrier Mix', 20.0, 0.0072612085771),
#  ('Siberian Husky-American English Coonhound Mix', 20.0, 0.15499573587),
#  ('American Staffordshire Terrier-Staffordshire Bull Terrier Mix', 20.0, 0.21109405458),
#  ('French Spaniel-German Shorthaired Pointer Mix', 20.0, 2.5458905945),
#  ('Siberian Husky-Keeshond Mix', 20.0, 0.00373111598465),
#  ('Chihuahua-Miniature Australian Shepherd Mix', 20.0, 0.15919407895),
#  ('Shetland Sheepdog-Cairn Terrier Mix', 20.0, 0.054103923),
#  ('Newfoundland-Poodle Mix', 20.0, 0.0498501462),
#  ('Vizsla-Dachshund Mix', 20.0, 0.6862627924),
#  ('Border Collie-Bernese Mountain Dog Mix', 20.0, 2.2172794834),
#  ('Cocker Spaniel-Labrador Retriever Mix', 20.0, 0.0053959551672),
#  ('Pointer-Bracco Italiano Mix', 20.0, 0.029541301173),
#  ('Chihuahua-Manchester Terrier Mix', 20.0, 0.87304641812),
#  ('American Pit Bull Terrier-Whippet Mix', 20.0, 0.15549403022),
#  ('Basset Hound-Pointer Mix', 20.0, 1.5358619639),
#  ('Labrador Retriever-English Cocker Spaniel Mix', 20.0, 0.10630482457),
#  ('Bernese Mountain Dog-Standard Poodle Mix', 20.0, 0.037240497076),
#  ('Newfoundland-Standard Poodle Mix', 20.0, 0.0027034600376),
#  ('Border Terrier-Standard Schnauzer Mix', 20.0, 0.14147782651),
#  ('Jack Russell Terrier-Shih Tzu Mix', 20.0, 1.2696412037),
#  ('Border Collie-Cavalier King Charles Spaniel Mix', 20.0, 0.57302997076),
#  ('Chow Chow-American Pit Bull Terrier Mix', 20.0, 0.029285453217),
#  ('Miniature Australian Shepherd-Shetland Sheepdog Mix', 20.0, 0.15247746101),
#  ('Jack Russell Terrier-German Shepherd Dog Mix', 20.0, 0.25689632066),
#  ('Jack Russell Terrier-Whippet Mix', 20.0, 0.041346856724),
#  ('Poodle-German Wirehaired Pointer Mix', 20.0, 0.054520589667),
#  ('Entlebucher Mountain Dog', 19.5, 3.4249987133175006),
#  ('Australian Cattle Dog-Rottweiler Mix', 19.0, 5.73617603615),
#  ('Australian Shepherd-Pembroke Welsh Corgi Mix', 18.5, 12.386820945750001),
#  ('-Labrador Retriever Mix', 18.5, 0.4309596531858333),
#  ('Rhodesian Ridgeback-Boxer Mix', 18.0, 6.210496609045),
#  ('Chow Chow-Cocker Spaniel Mix', 18.0, 0.24272399238),
#  ('Siberian Husky-American Pit Bull Terrier Mix', 18.0, 0.8499589627749999),
#  ('Brittany-Golden Retriever Mix', 18.0, 1.0089903322),
#  ('Jack Russell Terrier-Manchester Terrier Mix', 18.0, 1.4059150327),
#  ('Border Terrier- Mix', 17.0, 47.516506076),
#  ('Border Collie-Staffordshire Bull Terrier Mix', 17.0, 6.58801699264745),
#  ('Beagle-Pekingese Mix', 17.0, 0.3160474537),
#  ('Dachshund-Golden Retriever Mix', 17.0, 1.1026779514),
#  ('Beagle-Treeing Walker Coonhound Mix', 17.0, 0.94064655497),
#  ('Tibetan Terrier-Jack Russell Terrier Mix', 17.0, 0.0038447627302),
#  ('Shih Tzu-Bull Terrier Mix', 17.0, 0.0048191550959),
#  ('German Shepherd Dog-Treeing Walker Coonhound Mix', 17.0, 0.037144097223),
#  ('Bearded Collie-Tibetan Terrier Mix', 16.0, 1.6729351852),
#  ('Pug-Chihuahua Mix', 16.0, 0.3724982283373),
#  ('American Pit Bull Terrier-Pointer Mix', 16.0, 2.2505466339),
#  ('Puli', 16.0, 1.366494495066),
#  ('Old English Sheepdog-Poodle Mix', 16.0, 0.87233950618),
#  ('Bernese Mountain Dog-Poodle Mix', 16.0, 0.79423611111),
#  ('Parson Russell Terrier-Russell Terrier Mix', 16.0, 5.5366936728),
#  ('Parson Russell Terrier-Poodle Mix', 16.0, 1.8229164255399999),
#  ('Cirneco dell"Etna', 16.0, 34.06557716),
#  ('Poodle-Border Collie Mix', 16.0, 1.7376304012),
#  ('Italian Greyhound-Rat Terrier Mix', 16.0, 0.12858950618),
#  ('Brussels Griffon-Pug Mix', 16.0, 6.5951736111),
#  ('Yorkshire Terrier-Pomeranian Mix', 16.0, 0.6347692901249999),
#  ('Rhodesian Ridgeback-Vizsla Mix', 16.0, 1.4865316358),
#  ('Bulldog-Mastiff Mix', 16.0, 5.3904359568),
#  ('Boxer-Poodle Mix', 16.0, 0.19740740741),
#  ('Miniature Schnauzer-West Highland White Terrier Mix', 16.0, 0.46498533951),
#  ('Boston Terrier-Russell Terrier Mix', 16.0, 1.4104807099),
#  ('Maltese-Havanese Mix', 16.0, 0.073554783951),
#  ('Great Pyrenees-Bernese Mountain Dog Mix', 16.0, 0.53630478395),
#  ('Treeing Walker Coonhound-Pointer Mix', 16.0, 0.55284490741),
#  ('Wire Fox Terrier-Dachshund Mix', 16.0, 0.2012816358),
#  ('Border Collie-German Shorthaired Pointer Mix', 16.0, 0.26567515432),
#  ('Toy Fox Terrier-Australian Shepherd Mix', 16.0, 0.51981558641),
#  ('Wire Fox Terrier-Bulldog Mix', 16.0, 4.3090200617),
#  ('Belgian Sheepdog-Chow Chow Mix', 16.0, 0.0040200617243),
#  ('Whippet-Rat Terrier Mix', 16.0, 0.5925933642),
#  ('Hovawart-German Shepherd Dog Mix', 16.0, 0.26813657407),
#  ('Labrador Retriever-Airedale Terrier Mix', 16.0, 0.012069444444),
#  ('Airedale Terrier-Catahoula Leopard Dog Mix', 16.0, 0.06559027778),
#  ('American Eskimo Dog-Pomeranian Mix', 15.75, 2.229275899510225),
#  ('Pug-Beagle Mix', 15.666666666666666, 1.6168237698799999),
#  ('Chesapeake Bay Retriever-Labrador Retriever Mix', 15.666666666666666, 0.2666687648933),
#  ('Pug-Miniature Pinscher Mix', 15.5, 0.8303645529000001),
#  ('St. Bernard-Labrador Retriever Mix', 15.5, 19.580132858149998),
#  ('Norwegian Buhund', 15.5, 0.502212627942625),
#  ('American Staffordshire Terrier-Bullmastiff Mix', 15.5, 3.36341398635),
#  ('German Shepherd Dog-Australian Cattle Dog Mix', 15.5, 0.80189729532),
#  ('Cavalier King Charles Spaniel-Cocker Spaniel Mix', 15.5, 0.506909874515),
#  ('German Shepherd Dog-American Staffordshire Terrier Mix', 15.5, 1.0373426534899999),
#  ('Standard Schnauzer-Poodle Mix', 15.5, 1.76632547512),
#  ('Beagle-Poodle Mix', 15.5, 0.16206359649059998),
#  ('Black and Tan Coonhound-Labrador Retriever Mix', 15.5, 2.8468550421234),
#  ('Australian Cattle Dog-Border Collie Mix', 15.285714285714286, 3.0636628688944856),
#  ('Labrador Retriever-Golden Retriever Mix', 15.098445595854923, 2.1325582074738665),
#  ('Golden Retriever-Collie Mix', 15.0, 2.6743471754751673),
#  ('Cardigan Welsh Corgi-German Shepherd Dog Mix', 15.0, 14.067480910210465),
#  ('Cocker Spaniel-Bichon Frise Mix', 15.0, 1.3609689153),
#  ('Chihuahua-Poodle Mix', 15.0, 1.3629017857),
#  ('Border Collie-American Foxhound Mix', 15.0, 0.42811094576),
#  ('Australian Shepherd-Cocker Spaniel Mix', 15.0, 10.28676380008),
#  ('Keeshond-American Eskimo Dog Mix', 15.0, 0.5628546627),
#  ('Pomeranian-Toy Fox Terrier Mix', 15.0, 0.45163111772),
#  ('Rottweiler-Australian Cattle Dog Mix', 15.0, 0.0031630290989),
#  ('German Shepherd Dog-Basset Hound Mix', 15.0, 0.077318121696),
#  ('Australian Kelpie-Border Collie Mix', 15.0, 1.2208573082),
#  ('American Staffordshire Terrier-Lancashire Heeler Mix', 15.0, 0.14947751322),
#  ('St. Bernard-Standard Poodle Mix', 15.0, 0.4874875992),
#  ('Siberian Husky-Australian Shepherd Mix', 14.666666666666666, 0.47069424138410004),
#  ('Border Collie-Australian Cattle Dog Mix', 14.666666666666666, 3.293437869571638),
#  ('Beauceron', 14.666666666666666, 0.8373993314157777),
#  ('Vizsla- Mix', 14.5, 2.55558706275),
#  ('Tibetan Spaniel', 14.5, 0.044277756692975),
#  ('Akita-Siberian Husky Mix', 14.5, 0.74704861113),
#  ('Pointer-Labrador Retriever Mix', 14.333333333333334, 2.768804635029167),
#  ('Shetland Sheepdog-Border Collie Mix', 14.333333333333334, 0.8365184937073334),
#  ('Smooth Fox Terrier', 14.333333333333334, 2.147750080367367),
#  ('Labrador Retriever-Great Dane Mix', 14.333333333333334, 0.6321800174638167),
#  ('Bouvier des Flandres', 14.304347826086957, 2.648026494761222),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix', 14.0, 25.69619391),
#  ('Beagle-Schipperke Mix', 14.0, 1.4604220085),
#  ('German Shepherd Dog-Belgian Tervuren Mix', 14.0, 4.0148228276),
#  ('Affenpinscher', 14.0, 2.329358532114614),
#  ('Yorkshire Terrier- Mix', 14.0, 1.712513011371),
#  ('American Water Spaniel', 14.0, 2.5164384988462496),
#  ('Poodle-Lhasa Apso Mix', 14.0, 0.1774872617473333),
#  ('Miniature Pinscher-Chihuahua Mix', 14.0, 0.0043278133873),
#  ('Collie-German Shepherd Dog Mix', 14.0, 2.96307289037755),
#  ('German Shepherd Dog-Central Asian Shepherd Dog Mix', 14.0, 8.1535523504),
#  ('Australian Cattle Dog-Beagle Mix', 14.0, 1.933894414876),
#  ('German Shepherd Dog-Rhodesian Ridgeback Mix', 14.0, 0.32945906431550004),
#  ('American Staffordshire Terrier-Rhodesian Ridgeback Mix', 14.0, 0.49352653134),
#  ('Samoyed-Shetland Sheepdog Mix', 14.0, 0.0048940527037),
#  ('Basset Hound-Australian Shepherd Mix', 14.0, 0.92680555556),
#  ('Australian Shepherd-Bearded Collie Mix', 14.0, 19.336181446),
#  ('Pomeranian-American Eskimo Dog Mix', 14.0, 4.2303445513),
#  ('Golden Retriever-Bullmastiff Mix', 14.0, 1.7621323006),
#  ('American Pit Bull Terrier-Staffordshire Bull Terrier Mix', 14.0, 0.25604789886),
#  ('Miniature Schnauzer-Miniature Australian Shepherd Mix', 14.0, 6.0125694444),
#  ('Golden Retriever-Plott Mix', 14.0, 6.4317485755),
#  ('Beagle-Miniature Schnauzer Mix', 14.0, 3.5295405983),
#  ('Boston Terrier-American Staffordshire Terrier Mix', 14.0, 0.54194711538),
#  ('Toy Fox Terrier-Shih Tzu Mix', 14.0, 0.0039654558418),
#  ('German Shorthaired Pointer-Rottweiler Mix', 14.0, 0.5410042735),
#  ('Mastiff-Flat-Coated Retriever Mix', 14.0, 1.0177715456),
#  ('Giant Schnauzer', 13.875, 1.1128604980274126),
#  ('Golden Retriever-Labrador Retriever Mix', 13.79245283018868, 1.585933626900033),
#  ('Labrador Retriever-Collie Mix', 13.75, 1.333379563639425),
#  ('Poodle-Old English Sheepdog Mix', 13.5, 0.9255400219322499),
#  ('Pug-Wire Fox Terrier Mix', 13.5, 19.41625520825),
#  ('Chinese Crested-Poodle Mix', 13.5, 1.191301271095),
#  ('Field Spaniel', 13.5, 2.1095921069569665),
#  ('Russell Terrier-Beagle Mix', 13.5, 1.58415285901),
#  ('Flat-Coated Retriever- Mix', 13.5, 5.09897087172505),
#  ('Rat Terrier-Chihuahua Mix', 13.5, 2.2867756099179752),
#  ('Rat Terrier-Russell Terrier Mix', 13.5, 0.06856319037820001),
#  ('Golden Retriever-Chow Chow Mix', 13.5, 0.34720288133),
#  ('Yorkshire Terrier-Silky Terrier Mix', 13.5, 0.30755776883999997),
#  ('Belgian Malinois-Siberian Husky Mix', 13.5, 1.3957530864),
#  ('Bichon Frise-Cocker Spaniel Mix', 13.5, 0.24744776438235),
#  ('Pomeranian-Rat Terrier Mix', 13.5, 0.045207064239899994),
#  ('Poodle-Havanese Mix', 13.5, 0.169109151646),
#  ('Kooikerhondje', 13.4, 0.6318321393847601),
#  ('German Shorthaired Pointer-Labrador Retriever Mix', 13.4, 5.56805111269464),
#  ('Icelandic Sheepdog', 13.375, 1.434932758116),
#  ('Chihuahua-Italian Greyhound Mix', 13.333333333333334, 0.44755611056890005),
#  ('Komondor', 13.333333333333334, 0.1717414143999),
#  ('Australian Terrier', 13.23076923076923, 1.484946520760038),
#  ('Chihuahua-Russell Terrier Mix', 13.2, 2.09880986029894),
#  ('Pyrenean Shepherd', 13.142857142857142, 1.1799133743037),
#  ('Norwegian Elkhound', 13.0, 1.0191493797242857),
#  ('Afghan Hound', 13.0, 0.054121791749799995),
#  ('Cocker Spaniel-Cavalier King Charles Spaniel Mix', 13.0, 1.9395548115249999),
#  ('German Longhaired Pointer', 13.0, 0.0046199845674),
#  ('Golden Retriever-Basset Hound Mix', 13.0, 9.7423765432),
#  ('Shih Tzu-Dachshund Mix', 13.0, 0.089594907409),
#  ('Border Collie-Brittany Mix', 13.0, 1.1185006091799998),
#  ('Golden Retriever-Pembroke Welsh Corgi Mix', 13.0, 0.41833622685),
#  ('American Pit Bull Terrier-Bullmastiff Mix', 13.0, 0.14372890946333333),
#  ('Staffordshire Bull Terrier-Australian Cattle Dog Mix', 13.0, 0.2825464105411),
#  ('Shetland Sheepdog-Collie Mix', 13.0, 3.5150520833),
#  ('Cocker Spaniel-Miniature Pinscher Mix', 13.0, 1.5743836806),
#  ('Dogo Argentino-American Pit Bull Terrier Mix', 13.0, 1.0126099537),
#  ('Ibizan Hound-Greyhound Mix', 13.0, 1.0837606096),
#  ('Scottish Terrier', 12.894736842105264, 4.203243254491959),
#  ('German Shepherd Dog-Rottweiler Mix', 12.857142857142858, 0.38238124247139993),
#  ('Labrador Retriever-Australian Cattle Dog Mix', 12.833333333333334, 0.0800390540367),
#  ('Chow Chow-Labrador Retriever Mix', 12.75, 1.836372543055),
#  ('Border Collie-Shetland Sheepdog Mix', 12.75, 1.0800331123225),
#  ('Karelian Bear Dog', 12.666666666666666, 23.04480478396667),
#  ('Pekingese-Poodle Mix', 12.5, 6.689496121555225),
#  ('Bernese Mountain Dog-Great Pyrenees Mix', 12.5, 9.25829236715),
#  ('Pug-Boston Terrier Mix', 12.5, 0.563146569809),
#  ('Labrador Retriever-Rhodesian Ridgeback Mix', 12.5, 2.0052943497472504),
#  ('Miniature Schnauzer-Poodle Mix', 12.4375, 1.7950821466592375),
#  ('Australian Kelpie', 12.428571428571429, 1.2008747578988999),
#  ('Labrador Retriever- Mix', 12.25, 0.6630978719838875),
#  ('Wirehaired Pointing Griffon', 12.25, 7.4543815051253235),
#  ('Labrador Retriever-Weimaraner Mix', 12.2, 3.343075254027973),
#  ('Bichon Frise-Shih Tzu Mix', 12.1875, 3.063888059527606),
#  ('Samoyed', 12.185185185185185, 1.8929276733118743),
#  ('Australian Shepherd-Australian Cattle Dog Mix', 12.125, 1.0076739244788124),
#  ('Pembroke Welsh Corgi', 12.012195121951219, 1.9733657463585998),
#  ('German Shepherd Dog-Border Collie Mix', 12.0, 1.21200559412712),
#  ('Great Dane-Labrador Retriever Mix', 12.0, 2.99006599254465),
#  ('Danish-Swedish Farmdog', 12.0, 1.65858150586),
#  ('Pekingese-Dachshund Mix', 12.0, 3.8247359007),
#  ('American Pit Bull Terrier-Australian Cattle Dog Mix', 12.0, 0.0060111070636),
#  ('Dachshund-Yorkshire Terrier Mix', 12.0, 5.482507513204251),
#  ('Spanish Water Dog', 12.0, 0.8485111882585),
#  ('Shih Tzu-Pomeranian Mix', 12.0, 0.1071400869),
#  ('Beagle-Dachshund Mix', 12.0, 0.44999213556436674),
#  ('Siberian Husky-Rottweiler Mix', 12.0, 1.71194952080095),
#  ('Australian Cattle Dog-Siberian Husky Mix', 12.0, 0.00900351281525),
#  ('Border Collie-American Pit Bull Terrier Mix', 12.0, 0.20910148634034997),
#  ('Beagle-Chihuahua Mix', 12.0, 0.32042245370164996),
#  ('Catahoula Leopard Dog-Boxer Mix', 12.0, 0.092301136359),
#  ('Poodle-American Pit Bull Terrier Mix', 12.0, 3.6558964646),
#  ('Miniature Schnauzer-Wire Fox Terrier Mix', 12.0, 0.26605730183305004),
#  ('Whippet-Greyhound Mix', 12.0, 0.33969064734145),
#  ('Tibetan Spaniel-Papillon Mix', 12.0, 1.1170296717),
#  ('Bichon Frise-Cavalier King Charles Spaniel Mix', 11.88888888888889, 0.4862922589898666),
#  ('Poodle-Cavalier King Charles Spaniel Mix', 11.875, 4.6061583446888745),
#  ('Siberian Husky-German Shepherd Dog Mix', 11.823529411764707, 1.8017711571341177),
#  ('Cockapoo', 11.808080808080808, 2.695236968322324),
#  ('Shetland Sheepdog', 11.757352941176471, 1.611839077225289),
#  ('Beagle-Bluetick Coonhound Mix', 11.75, 0.3681107253008),
#  ('English Cocker Spaniel', 11.735294117647058, 1.2903594046628033),
#  ('Australian Cattle Dog- Mix', 11.666666666666666, 1.3967328493028333),
#  ('Labrador Retriever-Rottweiler Mix', 11.666666666666666, 1.2621621410007267),
#  ('Russell Terrier-Shih Tzu Mix', 11.666666666666666, 0.4776580097957999),
#  ('Dachshund-Poodle Mix', 11.666666666666666, 3.455122604798134),
#  ('Lowchen', 11.666666666666666, 3.8754897051446666),
#  ('Labrador Retriever-Pointer Mix', 11.666666666666666, 1.6140481448720667),
#  ('Labrador Retriever-Mastiff Mix', 11.666666666666666, 2.2014010721139),
#  ('Beagle-Parson Russell Terrier Mix', 11.666666666666666, 8.015555230529166),
#  ('Australian Cattle Dog-German Shepherd Dog Mix', 11.636363636363637, 0.5342523923573546),
#  ('Belgian Malinois', 11.625, 3.6383998982235766),
#  ('Norfolk Terrier', 11.625, 1.1113189215681998),
#  ('Collie-Shetland Sheepdog Mix', 11.5, 0.2004367689999),
#  ('Poodle-Maltese Mix', 11.5, 2.7944104524881643),
#  ('Boxer-Vizsla Mix', 11.5, 0.15715826024515),
#  ('German Shepherd Dog-Doberman Pinscher Mix', 11.5, 1.8216609630316665),
#  ('Smooth Fox Terrier-Whippet Mix', 11.5, 0.02315545808835),
#  ('Shorkie', 11.4, 3.0344475660450603),
#  ('Portuguese Water Dog', 11.383561643835616, 4.088287453223613),
#  ('Miniature American Shepherd', 11.37037037037037, 1.5618303339769297),
#  ('Australian Labradoodle', 11.342105263157896, 1.6031207675510917),
#  ('Australian Shepherd', 11.3342939481268, 3.8528150425820265),
#  ('French Spaniel', 11.333333333333334, 0.1036252346310333),
#  ('German Shepherd Dog-Boxer Mix', 11.333333333333334, 1.967085320800267),
#  ('Siberian Husky-American Staffordshire Terrier Mix', 11.333333333333334, 0.7027356717770666),
#  ('Border Collie-Greyhound Mix', 11.25, 0.2128300641624),
#  ('Australian Shepherd-Poodle Mix', 11.23076923076923, 8.8714236864904),
#  ('American Eskimo Dog', 11.083333333333334, 1.1938575695724503),
#  ('Soft Coated Wheaten Terrier', 11.08, 2.820401857593947),
#  ('Doberman Pinscher', 11.074766355140186, 2.1926382801614497),
#  ('Golden Retriever-Poodle Mix', 11.03125, 1.9526788891794316),
#  ('Maltese-Yorkshire Terrier Mix', 11.030303030303031, 1.0911764367453118),
#  ('Coton de Tulear', 11.026315789473685, 2.2412003633021866),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', 11.0, 2.8247997685),
#  ('Finnish Spitz', 11.0, 1.9830159599635),
#  ('Russell Terrier-Miniature Pinscher Mix', 11.0, 4.8150555556),
#  ('Pug-Smooth Fox Terrier Mix', 11.0, 2.8077060185),
#  ('Poodle-Dachshund Mix', 11.0, 0.001891203702),
#  ('Border Collie-Pembroke Welsh Corgi Mix', 11.0, 0.4970625),
#  ('Kerry Blue Terrier', 11.0, 4.617926389548266),
#  ('Briard', 11.0, 1.180592893411089),
#  ('German Shepherd Dog-Poodle Mix', 11.0, 0.2619434418689),
#  ('Border Collie-Saluki Mix', 11.0, 10.506555556),
#  ('Whippet-German Shepherd Dog Mix', 11.0, 11.182846065),
#  ('Dachshund-Doberman Pinscher Mix', 11.0, 1.0072685185),
#  ('American Pit Bull Terrier-Mastiff Mix', 11.0, 1.6008136574),
#  ('Pumi', 11.0, 0.22589236111),
#  ('Labrador Retriever-Boxer Mix', 11.0, 0.30358571485205),
#  ('Poodle-Chihuahua Mix', 11.0, 0.0061064814801),
#  ('Australian Cattle Dog-Anatolian Shepherd Dog Mix', 11.0, 0.0056944444425),
#  ('Border Collie-Collie Mix', 11.0, 1.0665393519),
#  ('Chinese Shar-Pei-Boerboel Mix', 11.0, 9.8942800926),
#  ('Border Collie-Flat-Coated Retriever Mix', 11.0, 0.20454166667),
#  ('Boxer-Golden Retriever Mix', 11.0, 0.0059224537108),
#  ('Miniature Schnauzer-Cairn Terrier Mix', 11.0, 0.00232669346225),
#  ('Bernese Mountain Dog-Rottweiler Mix', 11.0, 2.6285844907),
#  ('Airedale Terrier-German Shepherd Dog Mix', 11.0, 1.8820150463),
#  ('Beagle-Golden Retriever Mix', 11.0, 0.089871527778),
#  ('Silky Terrier-Lhasa Apso Mix', 11.0, 0.17006828703),
#  ('Cavalier King Charles Spaniel-Australian Shepherd Mix', 11.0, 0.28609606482),
#  ('Labrador Retriever-Catahoula Leopard Dog Mix', 11.0, 0.009951388894),
#  ('Basset Hound-Australian Cattle Dog Mix', 11.0, 0.51472222222),
#  ('Cocker Spaniel-Pug Mix', 11.0, 0.39873263888),
#  ('German Shepherd Dog-Shetland Sheepdog Mix', 11.0, 3.5086724537),
#  ('American Pit Bull Terrier-Cane Corso Mix', 11.0, 0.09715162036),
#  ('American Pit Bull Terrier-Treeing Tennessee Brindle Mix', 11.0, 1.1016851852),
#  ('Rottweiler-Komondor Mix', 11.0, 0.2075949074),
#  ('Miniature Australian Shepherd', 11.0, 0.6377978562257942),
#  ('German Shepherd Dog-Black and Tan Coonhound Mix', 11.0, 1.4042858796),
#  ('Papillon-English Springer Spaniel Mix', 11.0, 0.66553125001),
#  ('Mastiff-Great Pyrenees Mix', 11.0, 2.9080520833),
#  ('Bichon Frise-Miniature Schnauzer Mix', 11.0, 0.71050231481),
#  ('Australian Cattle Dog-Bull Terrier Mix', 11.0, 3.54268576389),
#  ('Siberian Husky-Greyhound Mix', 11.0, 1.3914293981),
#  ('Border Collie-Rhodesian Ridgeback Mix', 11.0, 1.8028668982),
#  ('Yorkshire Terrier-Havanese Mix', 11.0, 0.39891782408),
#  ('Border Collie-Pointer Mix', 11.0, 9.366431713),
#  ('Bloodhound-Bull Terrier Mix', 11.0, 0.0030740740707),
#  ('Yorkshire Terrier-Belgian Malinois Mix', 11.0, 0.0037627314801),
#  ('Dalmatian-Australian Shepherd Mix', 11.0, 0.003143518523),
#  ('Boxer-Australian Shepherd Mix', 11.0, 0.0065474537085),
#  ('Border Collie-Standard Poodle Mix', 11.0, 0.73831365741),
#  ('Treeing Walker Coonhound-Great Dane Mix', 11.0, 0.59670601852),
#  ('Brittany', 10.944444444444445, 2.894018846880694),
#  ('Collie', 10.944444444444445, 3.498487245739276),
#  ('English Setter', 10.875, 2.7832456012646247),
#  ('Irish Terrier', 10.857142857142858, 0.6467285589553572),
#  ('Gordon Setter', 10.833333333333334, 6.213487272324383),
#  ('Boykin Spaniel', 10.8, 9.207313907070102),
#  ('American Pit Bull Terrier-Boxer Mix', 10.8, 1.1073000892150533),
#  ('Irish Water Spaniel', 10.8, 0.19921847993588),
#  ('American Staffordshire Terrier-Bulldog Mix', 10.8, 6.857191662606081),
#  ('Nova Scotia Duck Tolling Retriever', 10.758620689655173, 1.084388223566524),
#  ('Doberman Pinscher-German Shepherd Dog Mix', 10.75, 0.445972704469225),
#  ('Poodle', 10.732782369146005, 2.6140056267611285),
#  ('Irish Red and White Setter', 10.666666666666666, 3.1416098572999993),
#  ('Swedish Vallhund', 10.666666666666666, 2.5491058723234334),
#  ('Black and Tan Coonhound', 10.666666666666666, 3.688111835333333),
#  ('Yorkshire Terrier-Shih Tzu Mix', 10.666666666666666, 2.6125851061714833),
#  ('Australian Shepherd-German Shepherd Dog Mix', 10.6, 5.1542462232916),
#  ('Border Collie-German Shepherd Dog Mix', 10.583333333333334, 0.5273001161269749),
#  ('Labrador Retriever', 10.57179054054054, 1.8896676377657677),
#  ('Weimaraner', 10.5625, 4.723160093619469),
#  ('Chinook', 10.5, 0.55994695214565),
#  ('Australian Shepherd- Mix', 10.5, 9.5612385195741),
#  ('Glen of Imaal Terrier', 10.5, 2.59568498398125),
#  ('Rhodesian Ridgeback-Labrador Retriever Mix', 10.5, 8.1680512662228),
#  ('Poodle-Rat Terrier Mix', 10.5, 0.411513462475),
#  ('Alaskan Malamute-Siberian Husky Mix', 10.5, 0.6331162889781),
#  ('Belgian Malinois-Labrador Retriever Mix', 10.5, 1.0686382458673498),
#  ('Jack Russell Terrier-Welsh Terrier Mix', 10.5, 0.0499061890815),
#  ('Greyhound-Border Collie Mix', 10.5, 0.132583150585),
#  ('Finnish Lapphund', 10.428571428571429, 7.349369266080843),
#  ('Yorkshire Terrier-Maltese Mix', 10.421052631578947, 0.886422716423621),
#  ('Border Collie-Australian Shepherd Mix', 10.4, 0.8498287163207833),
#  ('Keeshond', 10.4, 2.5351215299147998),
#  ('German Shorthaired Pointer', 10.372549019607844, 1.4175059913297199),
#  ('Border Terrier', 10.368421052631579, 6.445435546543581),
#  ('American Pit Bull Terrier-Rhodesian Ridgeback Mix', 10.333333333333334, 0.22445598466859998),
#  ('Rhodesian Ridgeback', 10.303030303030303, 2.4405302936503803),
#  ('Pointer', 10.285714285714286, 1.6444565058487854),
#  ('Standard Schnauzer', 10.25925925925926, 1.6486888879039772),
#  ('Australian Shepherd-Great Pyrenees Mix', 10.25, 0.241001345224975),
#  ('Golden Retriever', 10.227848101265822, 3.204662397880597),
#  ('Flat-Coated Retriever', 10.209302325581396, 0.7397042581606394),
#  ('Irish Setter', 10.1875, 0.4787406119291688),
#  ('Vizsla', 10.180555555555555, 1.5921877197388004),
#  ('Labradoodle', 10.17910447761194, 2.226187742407894),
#  ('Shih Tzu', 10.173913043478262, 3.3121220873538983),
#  ('Labrador Retriever-Border Collie Mix', 10.172413793103448, 3.0747741023069177),
#  ('Border Collie', 10.172131147540984, 2.5819207525320427),
#  ('Redbone Coonhound', 10.166666666666666, 0.5314457815773667),
#  ('West Highland White Terrier', 10.121621621621621, 0.5554775804463103),
#  ('Welsh Springer Spaniel', 10.083333333333334, 2.7887937986835),
#  ('Beagle', 10.076923076923077, 1.3825417699232716),
#  ('Puggle', 10.069767441860465, 0.6633284194715301),
#  ('German Shepherd Dog', 10.06338028169014, 1.937976011537341),
#  ('Golden Doodle', 10.043010752688172, 1.7037865867893902),
#  ('American Staffordshire Terrier-Labrador Retriever Mix', 10.0, 3.1057004548565),
#  ('German Shepherd Dog-Golden Retriever Mix', 10.0, 4.960440574397739),
#  ('Border Collie-Golden Retriever Mix', 10.0, 3.0006140966475368),
#  ('Doberman Pinscher-Black and Tan Coonhound Mix', 10.0, 1.6647710905),
#  ('Manchester Terrier', 10.0, 0.6890402046703399),
#  ('Chihuahua-Pembroke Welsh Corgi Mix', 10.0, 0.11420479305079999),
#  ('Pomeranian-Papillon Mix', 10.0, 5.648426697663766),
#  ('Bull Terrier-American Foxhound Mix', 10.0, 2.3275797325),
#  ('Siberian Husky-Alaskan Malamute Mix', 10.0, 0.0062114197581),
#  ('Standard Poodle-Chinese Shar-Pei Mix', 10.0, 12.801851852),
#  ('Lancashire Heeler-Australian Cattle Dog Mix', 10.0, 13.451033951),
#  ('Brittany-Pointer Mix', 10.0, 0.12342721194),
#  ('Siberian Husky-Boxer Mix', 10.0, 0.0042268518514),
#  ('Beagle-Jack Russell Terrier Mix', 10.0, 3.3353806584),
#  ('Poodle-Australian Cattle Dog Mix', 10.0, 0.47008873455565003),
#  ('Standard Poodle-Standard Schnauzer Mix', 10.0, 1.441877572),
#  ('Miniature Schnauzer', 9.969325153374234, 1.2734792956071666),
#  ('Cocker Spaniel', 9.96808510638298, 1.1704582350069945),
#  ('St. Bernard', 9.909090909090908, 2.4111468840442907),
#  ('Australian Cattle Dog', 9.905882352941177, 1.8415766384720682),
#  ('Shiba Inu', 9.88888888888889, 2.316236806516704),
#  ('Border Collie-Labrador Retriever Mix', 9.852941176470589, 2.956200986363276),
#  ('Belgian Tervuren', 9.833333333333334, 1.8208580707792277),
#  ('Dutch Shepherd', 9.833333333333334, 3.5071551729999086),
#  ('Cairn Terrier', 9.825, 0.9001780535685651),
#  ('Bedlington Terrier', 9.8, 0.8428044184604001),
#  ('German Shepherd Dog-Alaskan Malamute Mix', 9.8, 1.8530736447506797),
#  ('German Shepherd Dog-American Pit Bull Terrier Mix', 9.8, 12.69630711803298),
#  ('Poodle-Soft Coated Wheaten Terrier Mix', 9.8, 0.37746102240306),
#  ('Poodle-Miniature Schnauzer Mix', 9.73913043478261, 2.4237783592839652),
#  ('Pug', 9.700934579439252, 1.5859719530222194),
#  ('Norwich Terrier', 9.7, 2.0474561750867304),
#  ('Australian Cattle Dog-Labrador Retriever Mix', 9.7, 0.9972325478401001),
#  ('Mixed', 9.688152098307443, 2.223616312583437),
#  ('Chihuahua-Beagle Mix', 9.666666666666666, 0.9928040563400001),
#  ('Papillon', 9.634615384615385, 1.916449549871711),
#  ('Cocker Spaniel-Poodle Mix', 9.620689655172415, 0.8415586079159783),
#  ('Rat Terrier', 9.615384615384615, 2.2610525673210407),
#  ('Whippet', 9.612903225806452, 3.1291495583701296),
#  ('Silky Terrier', 9.6, 6.650067020066349),
#  ('German Shepherd Dog-Belgian Malinois Mix', 9.6, 0.21720612373884),
#  ('Lhasa Apso-Poodle Mix', 9.571428571428571, 13.850806990341328),
#  ('Siberian Husky', 9.548387096774194, 1.4976668648361608),
#  ('Akita', 9.541666666666666, 3.6264770154989923),
#  ('Cavalier King Charles Spaniel-Poodle Mix', 9.526315789473685, 1.042661282390189),
#  ('Rottweiler', 9.525641025641026, 0.80477371823935),
#  ('Mudi', 9.5, 0.276948905278875),
#  ('Alaskan Malamute', 9.5, 1.539097975832796),
#  ('Belgian Sheepdog', 9.5, 0.09104149746771667),
#  ('Beagle-American Eskimo Dog Mix', 9.5, 0.09485551698465),
#  ('German Pinscher', 9.5, 2.24254299667475),
#  ('Labrador Retriever-Doberman Pinscher Mix', 9.5, 0.78638514435),
#  ('Collie-Golden Retriever Mix', 9.5, 0.0754657187007),
#  ('Alaskan Malamute-German Shepherd Dog Mix', 9.5, 0.04399813189809999),
#  ('Chihuahua-Yorkshire Terrier Mix', 9.454545454545455, 0.981292650409791),
#  ('Catahoula Leopard Dog', 9.444444444444445, 0.7616294620280556),
#  ('Cardigan Welsh Corgi', 9.428571428571429, 0.42124601144150003),
#  ('Greyhound', 9.425925925925926, 5.007718608715576),
#  ('Wire Fox Terrier', 9.416666666666666, 3.955996065644934),
#  ('Bernese Mountain Dog', 9.404255319148936, 4.432021421608243),
#  ('German Shepherd Dog-Siberian Husky Mix', 9.35, 1.0713987681749753),
#  ('English Springer Spaniel', 9.339285714285714, 2.7658098310491352),
#  ('German Shepherd Dog-Beagle Mix', 9.333333333333334, 7.4778517910336),
#  ('American Staffordshire Terrier-Border Collie Mix', 9.333333333333334, 4.3930970936269),
#  ('Pug-Shih Tzu Mix', 9.333333333333334, 0.5598594190090332),
#  ('Boxer', 9.329842931937172, 1.9380014470422384),
#  ('Cavalier King Charles Spaniel-Bichon Frise Mix', 9.272727272727273, 1.8916859064790275),
#  ('Labrador Retriever-German Shepherd Dog Mix', 9.25, 1.6552339865235537),
#  ('Mastiff', 9.238095238095237, 0.2379506004284999),
#  ('Boxer-American Staffordshire Terrier Mix', 9.2, 1.44613055554656),
#  ('Chinese Shar-Pei', 9.2, 1.13619762291552),
#  ('Greyhound-Labrador Retriever Mix', 9.2, 0.63571373456002),
#  ('Siberian Husky-Labrador Retriever Mix', 9.2, 0.20757885396216),
#  ('Dalmatian', 9.1875, 2.163043660881169),
#  ('American Staffordshire Terrier', 9.175438596491228, 1.4295162387625278),
#  ('Pomapoo', 9.166666666666666, 0.8478138230969083),
#  ('Newfoundland', 9.151515151515152, 1.4171868074229486),
#  ('Old English Sheepdog', 9.125, 4.290641060012963),
#  ('Australian Cattle Dog-Australian Shepherd Mix', 9.125, 0.6217459046590625),
#  ('Bichon Frise', 9.05, 0.8793270623742288),
#  ('French Bulldog', 9.0, 3.6216683711218183),
#  ('Shih Tzu-Maltese Mix', 9.0, 0.8452275114113248),
#  ('Irish Wolfhound', 9.0, 6.920690081026001),
#  ('Treeing Walker Coonhound', 9.0, 1.7088551952761644),
#  ('Spinone Italiano', 9.0, 1.7740784397366667),
#  ('Labrador Retriever-American Pit Bull Terrier Mix', 9.0, 0.9885283846079953),
#  ('Borzoi', 9.0, 0.0051027199081),
#  ('Basset Hound-German Shepherd Dog Mix', 9.0, 2.00214660489265),
#  ('Boxer- Mix', 9.0, 0.5685809888187),
#  ('Keeshond-Chow Chow Mix', 9.0, 5.778322723800001),
#  ('-Boxer Mix', 9.0, 1.9567307098597),
#  ('Chihuahua-Cardigan Welsh Corgi Mix', 9.0, 1.53680208332045),
#  ('Siberian Husky-Border Collie Mix', 9.0, 0.978127700605),
#  ('Havanese-Shih Tzu Mix', 9.0, 45.379185475),
#  ('Bulldog-Bullmastiff Mix', 9.0, 4.851057581),
#  ('Plott', 9.0, 0.26811620100466665),
#  ('Soft Coated Wheaten Terrier-Poodle Mix', 9.0, 0.15568431713),
#  ('American Eskimo Dog-Shiba Inu Mix', 9.0, 0.88812789351),
#  ('Greyhound-Irish Wolfhound Mix', 9.0, 3.633708044),
#  ('Italian Greyhound-Miniature Pinscher Mix', 9.0, 0.928472800925),
#  ('Chesapeake Bay Retriever-Siberian Husky Mix', 9.0, 0.0259084164222),
#  ('Australian Terrier-Parson Russell Terrier Mix', 9.0, 15.641127025),
#  ('Boston Terrier-Pomeranian Mix', 9.0, 1.206399112675),
#  ('American Staffordshire Terrier-Dogue de Bordeaux Mix', 9.0, 1.52801816237),
#  ('Catahoula Leopard Dog-Bluetick Coonhound Mix', 9.0, 0.01452857904985),
#  ('Plott-Labrador Retriever Mix', 9.0, 0.87850405094),
#  ('Dutch Shepherd-Labrador Retriever Mix', 9.0, 5.8578110532),
#  ('Maltese-Shih Tzu Mix', 8.923076923076923, 0.578801255495877),
#  ('Welsh Terrier', 8.916666666666666, 1.13315796578885),
#  ('Lagotto Romagnolo', 8.88888888888889, 2.136297137840856),
#  ('Labrador Retriever-Beagle Mix', 8.875, 1.2094622747655626),
#  ('Other', 8.82258064516129, 1.6351948170484993),
#  ('Bull Terrier', 8.8, 0.7085022884517401),
#  ('Labrador Retriever-Siberian Husky Mix', 8.8, 0.7104832175862),
#  ('Labrador Retriever-Dachshund Mix', 8.75, 0.1501003086371),
#  ('Petit Basset Griffon Vendeen', 8.75, 0.095962957889275),
#  ('Mastiff-Labrador Retriever Mix', 8.75, 0.939057745159475),
#  ('Havanese-Poodle Mix', 8.714285714285714, 2.0968299591029287),
#  ('Neapolitan Mastiff', 8.666666666666666, 1.1492396935644333),
#  ('Poodle-Golden Retriever Mix', 8.666666666666666, 0.5191230319705084),
#  ('American Pit Bull Terrier', 8.654929577464788, 1.387803735633341),
#  ('German Wirehaired Pointer', 8.642857142857142, 0.26757245109687855),
#  ('Chihuahua-Pug Mix', 8.625, 2.2825944456544254),
#  ('Lhasa Apso', 8.6, 1.9326610752702067),
#  ('Poodle-Labrador Retriever Mix', 8.6, 0.065170321636),
#  ('Labrador Retriever-German Shorthaired Pointer Mix', 8.571428571428571, 0.08511810776535714),
#  ('Chihuahua-Dachshund Mix', 8.521739130434783, 0.9349264465668736),
#  ("I Don't Know", 8.515981735159817, 1.1385614884027997),
#  ('American Staffordshire Terrier-American Pit Bull Terrier Mix', 8.5, 11.305368635504038),
#  ('German Shorthaired Pointer-American Pit Bull Terrier Mix', 8.5, 9.3038036265),
#  ('Boxer-Labrador Retriever Mix', 8.5, 0.3555833000228271),
#  ('Akita-German Shepherd Dog Mix', 8.5, 1.0470523313518498),
#  ('Berger Picard', 8.4, 13.6870421540363),
#  ('Cavalier King Charles Spaniel', 8.382978723404255, 3.758196579178509),
#  ('Standard Poodle', 8.372549019607844, 0.35947493085381815),
#  ('Catahoula Leopard Dog-Australian Cattle Dog Mix', 8.333333333333334, 0.123566439249),
#  ('Border Collie-Siberian Husky Mix', 8.333333333333334, 0.4058011154317834),
#  ('Yorkshire Terrier-Miniature Schnauzer Mix', 8.333333333333334, 0.9538333184980151),
#  ('Doberman Pinscher-Rottweiler Mix', 8.333333333333334, 0.42316813973333334),
#  ('Border Collie-Australian Kelpie Mix', 8.333333333333334, 1.1459834500722998),
#  ('Havanese', 8.309278350515465, 2.2597245913335375),
#  ('Japanese Chin', 8.285714285714286, 0.4203288506786285),
#  ('Maltese-Poodle Mix', 8.26923076923077, 2.9568497884069416),
#  ('Boston Terrier', 8.247706422018348, 1.1992486544663883),
#  ('Miniature Pinscher', 8.229166666666666, 1.0535985870908673),
#  ('Greater Swiss Mountain Dog', 8.222222222222221, 0.3653669043563111),
#  ('Chesapeake Bay Retriever', 8.210526315789474, 1.5674799599404052),
#  ('Bulldog', 8.2, 2.209346130121479),
#  ('Boston Terrier-French Bulldog Mix', 8.2, 0.03284070012324),
#  ('Bichon Frise-Poodle Mix', 8.136363636363637, 1.5154235993976635),
#  ('Labrador Retriever-Australian Shepherd Mix', 8.1, 0.45019518559484994),
#  ('Basenji', 8.071428571428571, 0.7641072514192785),
#  ('Dachshund', 8.054545454545455, 1.4720505957567276),
#  ('Great Dane', 8.0, 0.8270445525626678),
#  ('American Staffordshire Terrier- Mix', 8.0, 2.9240757984849997),
#  ('Poodle-German Spitz Mix', 8.0, 0.2521577381),
#  ('Boerboel', 8.0, 0.9688064997579999),
#  ('Pembroke Welsh Corgi-Chihuahua Mix', 8.0, 0.8031747685299999),
#  ('Greyhound-American Pit Bull Terrier Mix', 8.0, 0.15403439154),
#  ('Rottweiler-American Pit Bull Terrier Mix', 8.0, 0.6202868559776499),
#  ('Dachshund-American Staffordshire Terrier Mix', 8.0, 6.108083664),
#  ('Lhasa Apso-Tibetan Spaniel Mix', 8.0, 6.8745171958),
#  ('Russell Terrier', 7.956521739130435, 1.596863923727489),
#  ('Yorkshire Terrier-Poodle Mix', 7.916666666666667, 1.57070169075027),
#  ('Yorkshire Terrier', 7.893939393939394, 1.241958561657786),
#  ('American Pit Bull Terrier-American Staffordshire Terrier Mix', 7.875, 1.898817432754275),
#  ('Pomeranian', 7.833333333333333, 3.392385605657543),
#  ('German Shepherd Dog-Australian Shepherd Mix', 7.833333333333333, 0.4192346359915334),
#  ('Toy Fox Terrier', 7.833333333333333, 1.0799278870950333),
#  ('Xoloitzcuintli', 7.8, 1.90605532407634),
#  ('German Shepherd Dog-Labrador Retriever Mix', 7.777777777777778, 0.8641366182407333),
#  ('Poodle-Cocker Spaniel Mix', 7.75, 1.796837007740796),
#  ('Pekingese', 7.75, 0.8753548183517875),
#  ('Australian Shepherd-Shetland Sheepdog Mix', 7.75, 0.00344607902595),
#  ('Chinese Crested', 7.7272727272727275, 0.9797398188070727),
#  ('Beagle-Labrador Retriever Mix', 7.6923076923076925, 0.48017161537575376),
#  ('Australian Shepherd-Border Collie Mix', 7.6875, 0.8848417320101878),
#  ('Chihuahua', 7.681818181818182, 1.2883960302636646),
#  ('Boxer-Bulldog Mix', 7.666666666666667, 0.7093005952518334),
#  ('Border Collie-Newfoundland Mix', 7.666666666666667, 0.39282531060549997),
#  ('Borzoi-Whippet Mix', 7.666666666666667, 13.062376929000001),
#  ('Golden Retriever-Border Collie Mix', 7.666666666666667, 1.659210664230767),
#  ('Parson Russell Terrier', 7.661538461538462, 1.7783979651768151),
#  ('Poodle-Yorkshire Terrier Mix', 7.642857142857143, 1.5176645514222216),
#  ('Labrador Retriever-Chinese Shar-Pei Mix', 7.6, 0.88441143689576),
#  ('Poodle-Bichon Frise Mix', 7.6, 1.2236292641318198),
#  ('Eurasier', 7.6, 0.9251408991226002),
#  ('Labrador Retriever-Poodle Mix', 7.6, 5.101454489341114),
#  ('Bullmastiff', 7.538461538461538, 0.15347951966784618),
#  ('Australian Shepherd-Golden Retriever Mix', 7.5, 5.232328869045425),
#  ('Miniature Bull Terrier', 7.5, 0.0055690586009),
#  ('Bearded Collie', 7.5, 2.1437961508000147),
#  ('Havanese-Maltese Mix', 7.5, 0.72742091050885),
#  ('Chihuahua-Labrador Retriever Mix', 7.5, 0.0025180500411),
#  ('Maltese', 7.409638554216867, 2.1480339724486734),
#  ('Yorkshire Terrier-Bichon Frise Mix', 7.4, 0.61638856622112),
#  ('Cane Corso', 7.3076923076923075, 0.4014551771112308),
#  ('Shih Tzu-Poodle Mix', 7.291666666666667, 0.25461690891710836),
#  ('Czechoslovakian Vlcak', 7.25, 0.2516850938112),
#  ('Border Collie-Cocker Spaniel Mix', 7.25, 1.330182388131925),
#  ('Brussels Griffon', 7.235294117647059, 0.7067501069060708),
#  ('Stabyhoun', 7.2, 0.37850835769074004),
#  ('Leonberger', 7.181818181818182, 3.1076551941047),
#  ('Labrador Retriever-Greyhound Mix', 7.166666666666667, 0.48200177333349997),
#  ('Belgian Sheepdog- Mix', 7.0, 1.5139911265),
#  ('Border Collie-Belgian Tervuren Mix', 7.0, 0.0028260030859),
#  ('Staffordshire Bull Terrier-Great Dane Mix', 7.0, 3.6205169753),
#  ('Staffordshire Bull Terrier-Miniature Schnauzer Mix', 7.0, 0.49111496913),
#  ('Great Dane-Irish Wolfhound Mix', 7.0, 0.002949459886),
#  ('Pembroke Welsh Corgi-Great Pyrenees Mix', 7.0, 0.17579861111),
#  ('Dandie Dinmont Terrier', 7.0, 0.0038117284035),
#  ('Pointer-Beagle Mix', 7.0, 0.0039834105018),
#  ('Golden Retriever-English Cocker Spaniel Mix', 7.0, 103.47309799),
#  ('German Shepherd Dog-Chinese Shar-Pei Mix', 7.0, 1.7757175926004),
#  ('Dogo Argentino', 7.0, 0.10810532407385),
#  ('American Foxhound- Mix', 7.0, 0.0038136574051),
#  ('Bedlington Terrier-Whippet Mix', 7.0, 11.850871914),
#  ('Otterhound', 7.0, 20.525237269),
#  ('Basset Hound-Russell Terrier Mix', 7.0, 0.0036265432136),
#  ('Airedale Terrier-Labrador Retriever Mix', 7.0, 0.64892344576),
#  ('Shih Tzu-Chihuahua Mix', 7.0, 0.33915895063),
#  ('Miniature Schnauzer-Maltese Mix', 7.0, 3.7078780864),
#  ('Redbone Coonhound-Basset Hound Mix', 7.0, 0.0024093364292),
#  ('Doberman Pinscher-Pug Mix', 7.0, 0.0025983796216),
#  ('Bulldog-Chesapeake Bay Retriever Mix', 7.0, 1.680773534),
#  ('Catahoula Leopard Dog-Siberian Husky Mix', 7.0, 1.9063464506),
#  ('Scottish Deerhound', 7.0, 0.807872299375),
#  ('-Toy Fox Terrier Mix', 7.0, 5.0518827161),
#  ('German Shorthaired Pointer- Mix', 7.0, 0.030200617291),
#  ('American Pit Bull Terrier-German Shepherd Dog Mix', 7.0, 0.004567901235),
#  ('Lhasa Apso-Shih Tzu Mix', 7.0, 0.5632750495895333),
#  ('Mastiff-American Pit Bull Terrier Mix', 7.0, 0.0066705246961),
#  ('Scottish Terrier-Shih Tzu Mix', 7.0, 4.9845543981),
#  ('Russell Terrier-Cocker Spaniel Mix', 7.0, 0.21762924383),
#  ('Maltese-Pomeranian Mix', 7.0, 1.1627064043),
#  ('Pointer-Australian Shepherd Mix', 7.0, 0.0048167438366),
#  ('Belgian Malinois- Mix', 7.0, 0.0050096450523),
#  ('American Eskimo Dog- Mix', 7.0, 0.46420910493),
#  ('Cardigan Welsh Corgi-Cairn Terrier Mix', 7.0, 0.0036535493757),
#  ('Basenji-Shiba Inu Mix', 7.0, 0.0034702932075),
#  ('Beagle-Whippet Mix', 7.0, 5.6779475309),
#  ('French Bulldog-Pug Mix', 7.0, 0.0051581790128),
#  ('American Staffordshire Terrier-Chinese Shar-Pei Mix', 7.0, 0.0059375000028),
#  ('German Shepherd Dog-Whippet Mix', 7.0, 0.1805324074),
#  ('Border Collie-West Highland White Terrier Mix', 7.0, 0.0039525462972),
#  ('Pug-Russell Terrier Mix', 7.0, 7.9727411265),
#  ('Australian Cattle Dog-Bluetick Coonhound Mix', 7.0, 0.18724729938),
#  ('American Foxhound-Labrador Retriever Mix', 7.0, 2.1435435957),
#  ('Russell Terrier-Rat Terrier Mix', 7.0, 0.15227623457),
#  ('Australian Cattle Dog-Weimaraner Mix', 7.0, 0.005929783937),
#  ('Siberian Husky-Standard Schnauzer Mix', 7.0, 1.8291415895),
#  ('Labrador Retriever-Cocker Spaniel Mix', 7.0, 0.5043161651188001),
#  ('Bichon Frise-Pomeranian Mix', 7.0, 0.002075617299),
#  ('Border Collie-Kooikerhondje Mix', 7.0, 11.04314429),
#  ('Border Collie-Chow Chow Mix', 7.0, 5.8167052469),
#  ('Border Terrier-Parson Russell Terrier Mix', 7.0, 0.12707561728),
#  ('Siberian Husky-Bernese Mountain Dog Mix', 7.0, 0.34788773149),
#  ('Black and Tan Coonhound-German Shepherd Dog Mix', 7.0, 0.004643132716),
#  ('Havanese-Bichon Frise Mix', 7.0, 10.018680556),
#  ('Boxer-Rhodesian Ridgeback Mix', 7.0, 1.3573476080400002),
#  ('Great Pyrenees-Golden Retriever Mix', 7.0, 0.0045081018467),
#  ('American English Coonhound-Rhodesian Ridgeback Mix', 7.0, 0.012108410495),
#  ('St. Bernard-Dachshund Mix', 7.0, 4.9820158179),
#  ('Maltese-Cavalier King Charles Spaniel Mix', 7.0, 0.17082368829),
#  ('Chihuahua-Norwich Terrier Mix', 7.0, 0.48535493827),
#  ('American Staffordshire Terrier-Greyhound Mix', 7.0, 0.50112075617),
#  ('Basenji-Whippet Mix', 7.0, 2.1461091821),
#  ('Plott-Beagle Mix', 7.0, 0.0054320987744),
#  ('Flat-Coated Retriever-Portuguese Water Dog Mix', 7.0, 1.3049807099),
#  ('Miniature Pinscher-Russell Terrier Mix', 7.0, 0.0059702932094),
#  ('German Shepherd Dog-Bluetick Coonhound Mix', 7.0, 14.331429398),
#  ('Wire Fox Terrier-Parson Russell Terrier Mix', 7.0, 0.16227623457),
#  ('Parson Russell Terrier-Cairn Terrier Mix', 7.0, 3.3470756173),
#  ('Russell Terrier-Golden Retriever Mix', 7.0, 0.78516203702),
#  ('Boxer-Boston Terrier Mix', 7.0, 0.34714699073),
#  ('Akita-Bernese Mountain Dog Mix', 7.0, 15.506456404),
#  ('Basset Hound-Cardigan Welsh Corgi Mix', 7.0, 0.22298032408),
#  ('American Pit Bull Terrier-Chinese Shar-Pei Mix', 7.0, 0.065426311727),
#  ('Karelian Bear Dog-Border Collie Mix', 7.0, 1.6305767747),
#  ('Boxer-American Foxhound Mix', 7.0, 0.0030304783913),
#  ('Brittany-Siberian Husky Mix', 7.0, 0.68300925927),
#  ('Great Pyrenees-Chow Chow Mix', 7.0, 1.2864409722),
#  ('Papillon-Miniature Schnauzer Mix', 7.0, 0.0072067901103),
#  ('Papillon-Pomeranian Mix', 7.0, 1.3517110339),
#  ('Border Collie-Affenpinscher Mix', 7.0, 3.3240046296),
#  ('Australian Labradoodle-Poodle Mix', 7.0, 0.00474054783505),
#  ('Japanese Chin-Pekingese Mix', 7.0, 0.0056693672858),
#  ('American Pit Bull Terrier-Vizsla Mix', 7.0, 0.13390239198),
#  ('Labrador Retriever-Pomeranian Mix', 7.0, 0.0085725308548),
#  ('Lhasa Apso-Dandie Dinmont Terrier Mix', 7.0, 0.16481867283),
#  ('Collie-Belgian Malinois Mix', 7.0, 0.022617669757),
#  ('Chinese Shar-Pei-Australian Cattle Dog Mix', 7.0, 0.0045621141905),
#  ('Shetland Sheepdog-American Eskimo Dog Mix', 7.0, 0.004274691358),
#  ('Golden Retriever-Irish Wolfhound Mix', 7.0, 0.0081018518542),
#  ('Lhasa Apso-German Shepherd Dog Mix', 7.0, 0.0063387345674),
#  ('Poodle-Redbone Coonhound Mix', 7.0, 2.285163966),
#  ('Chihuahua-Australian Terrier Mix', 7.0, 0.1881712963),
#  ('Australian Cattle Dog-Chow Chow Mix', 7.0, 0.003252314811),
#  ('Brussels Griffon-Poodle Mix', 7.0, 0.33560378085),
#  ('Bulldog-Labrador Retriever Mix', 7.0, 0.87117862655),
#  ('Yorkshire Terrier-German Spitz Mix', 7.0, 0.0033487654293),
#  ('Dachshund-American Pit Bull Terrier Mix', 7.0, 0.057609953704),
#  ('Bichon Frise-Havanese Mix', 7.0, 1.00515625),
#  ('Pekingese-Lhasa Apso Mix', 7.0, 1.3636149691),
#  ('Cocker Spaniel-English Cocker Spaniel Mix', 7.0, 0.0084895833282),
#  ('Brussels Griffon-Border Terrier Mix', 7.0, 0.22055555556),
#  ('German Shorthaired Pointer-Newfoundland Mix', 7.0, 1.839220679),
#  ('Plott-American Foxhound Mix', 7.0, 3.1869290123),
#  ('Golden Retriever-Redbone Coonhound Mix', 7.0, 0.0044579475266),
#  ('Cairn Terrier-Australian Terrier Mix', 7.0, 0.004081790122),
#  ('Jack Russell Terrier-Poodle Mix', 7.0, 0.16815972223),
#  ('Golden Retriever-Cavalier King Charles Spaniel Mix', 7.0, 0.012276234571),
#  ('Bullmastiff-Dogue de Bordeaux Mix', 7.0, 0.0030729166469),
#  ('Smooth Fox Terrier-Bluetick Coonhound Mix', 7.0, 1.3163541667),
#  ('Australian Shepherd-Pug Mix', 7.0, 0.0069791666657),
#  ('Jack Russell Terrier', 6.985074626865671, 0.2606110003162895),
#  ('Chihuahua-Miniature Pinscher Mix', 6.909090909090909, 6.556688061811635),
#  ('Basset Hound', 6.777777777777778, 0.9025569762253833),
#  ('Jack-A-Poo', 6.75, 0.33579740548445003),
#  ('Beagle-Rat Terrier Mix', 6.75, 0.51598333942275),
#  ('Australian Cattle Dog-American Pit Bull Terrier Mix', 6.666666666666667, 0.0397958214522),
#  ('Beagle-Cocker Spaniel Mix', 6.666666666666667, 1.6740815329671666),
#  ('American Pit Bull Terrier-Labrador Retriever Mix', 6.631578947368421, 1.678277249668989),
#  ('Great Pyrenees', 6.615384615384615, 0.3167793718199616),
#  ('Chihuahua- Mix', 6.5, 0.29999961419545),
#  ('Silky Terrier-Poodle Mix', 6.5, 2.8986786265578),
#  ('Canaan Dog', 6.5, 0.11029699901727501),
#  ('Australian Shepherd-Rottweiler Mix', 6.5, 1.0400939428965001),
#  ('Catahoula Leopard Dog-Labrador Retriever Mix', 6.5, 0.39716203364095004),
#  ('Shih Tzu-Bichon Frise Mix', 6.5, 1.3324525463080876),
#  ('German Shepherd Dog-Greyhound Mix', 6.5, 0.07712114198690001),
#  ('Bull Terrier-Labrador Retriever Mix', 6.5, 0.0033171296331999996),
#  ('Mastiff-Great Dane Mix', 6.5, 0.3418611111462),
#  ('Bichon Frise-Lhasa Apso Mix', 6.5, 0.55408661265),
#  ('Poodle-English Springer Spaniel Mix', 6.5, 9.6326933835104),
#  ('Boxer-American Pit Bull Terrier Mix', 6.375, 0.1107159250178125),
#  ('Chow Chow', 6.375, 0.0619299768538875),
#  ('Labrador Retriever-American Staffordshire Terrier Mix', 6.333333333333333, 0.003380658428166667),
#  ('Staffordshire Bull Terrier', 6.275862068965517, 1.9078861000836589),
#  ('Doberman Pinscher-Labrador Retriever Mix', 6.25, 4.908304205303399),
#  ('American Staffordshire Terrier-Boxer Mix', 6.25, 0.4658477101463375),
#  ('Tibetan Terrier', 6.2105263157894735, 1.3653165813868526),
#  ('Black Russian Terrier', 6.2, 0.24104300681155996),
#  ('Schipperke', 6.111111111111111, 7.654040175373743),
#  ('Boykin Spaniel-Deutscher Wachtelhund Mix', 6.0, 65.255203704),
#  ('Staffordshire Bull Terrier-Russell Terrier Mix', 6.0, 0.016523148142),
#  ('German Spitz', 6.0, 0.23934363975152856),
#  ('Boxer-Bull Terrier Mix', 6.0, 0.39743287037),
#  ('Russell Terrier- Mix', 6.0, 0.0052638888821),
#  ('St. Bernard- Mix', 6.0, 1.221537037),
#  ('Beagle-Siberian Husky Mix', 6.0, 0.0072615740826),
#  ('Shih Tzu-Silky Terrier Mix', 6.0, 1.4065763889),
#  ('Rat Terrier-Beagle Mix', 6.0, 0.67501851851),
#  ('Beagle-Border Collie Mix', 6.0, 3.3991813914414153),
#  ('Irish Setter-Border Collie Mix', 6.0, 22.621259259),
#  ('Golden Retriever-Cocker Spaniel Mix', 6.0, 0.00430844907515),
#  ('Labrador Retriever-Pembroke Welsh Corgi Mix', 6.0, 5.357849537),
#  ('Cardigan Welsh Corgi-Lancashire Heeler Mix', 6.0, 0.0042777777648),
#  ('Chihuahua-Toy Fox Terrier Mix', 6.0, 0.83833622685),
#  ('Pekingese-Cocker Spaniel Mix', 6.0, 0.0049745370404),
#  ('Labrador Retriever-Great Pyrenees Mix', 6.0, 0.022800925933),
#  ('Plott-Boxer Mix', 6.0, 0.20016435187),
#  ('Rottweiler-Collie Mix', 6.0, 0.018474537041),
#  ('Miniature Australian Shepherd-Poodle Mix', 6.0, 1.0159884259),
#  ('Australian Cattle Dog-Australian Kelpie Mix', 6.0, 0.091194444429),
#  ('Miniature Schnauzer-Soft Coated Wheaten Terrier Mix', 6.0, 0.0042847222183),
#  ('Jack Russell Terrier-Smooth Fox Terrier Mix', 6.0, 0.14415046296),
#  ('Jindo-Shiba Inu Mix', 6.0, 1.5802291667),
#  ('Golden Retriever-German Shepherd Dog Mix', 5.875, 3.746174641677975),
#  ('Dachshund-Chihuahua Mix', 5.875, 5.3005950241233375),
#  ('Italian Greyhound', 5.84, 2.165570224751164),
#  ('Dachshund-Miniature Pinscher Mix', 5.75, 0.2794860146655),
#  ('Chihuahua-Rat Terrier Mix', 5.75, 0.713882233782025),
#  ('Small Munsterlander Pointer', 5.666666666666667, 0.06374935699646667),
#  ('Bulldog-Boxer Mix', 5.666666666666667, 1.44606995882),
#  ('Airedale Terrier', 5.6, 0.68543428870179),
#  ('Staffordshire Bull Terrier-Bulldog Mix', 5.5, 0.00326292436975),
#  ('Labrador Retriever-English Springer Spaniel Mix', 5.5, 0.00293499226445),
#  ('Labrador Retriever-St. Bernard Mix', 5.5, 39.01976562512955),
#  ('Dogue de Bordeaux', 5.5, 0.0038638117258),
#  ('Australian Shepherd-Labrador Retriever Mix', 5.5, 0.33947022324730003),
#  ('St. Bernard-Border Collie Mix', 5.5, 0.0048775077257),
#  ('Siberian Husky-Beagle Mix', 5.5, 5.4115258489217),
#  ('Australian Shepherd-Siberian Husky Mix', 5.5, 0.6688097029397501),
#  ('Australian Shepherd-Collie Mix', 5.5, 0.43882330246),
#  ('Jack Russell Terrier-American Pit Bull Terrier Mix', 5.5, 0.00379050924655),
#  ('Poodle-Shih Tzu Mix', 5.363636363636363, 3.862693427302418),
#  ('Beagle-Australian Cattle Dog Mix', 5.333333333333333, 0.4085299639845),
#  ('BullBoxer', 5.333333333333333, 0.08733010076905334),
#  ('Collie-Labrador Retriever Mix', 5.333333333333333, 0.24521540639716666),
#  ('Jindo', 5.333333333333333, 0.12241158693433334),
#  ('Boxer-Border Collie Mix', 5.0, 0.0037355324018),
#  ('German Shepherd Dog-Chow Chow Mix', 5.0, 1.5593018123804665),
#  ('Bugg', 5.0, 7.801820794784624),
#  ('Lakeland Terrier', 5.0, 4.27426183112),
#  ('Chesapeake Bay Retriever-Beagle Mix', 5.0, 0.0037847222116),
#  ('Cairn Terrier-Shih Tzu Mix', 5.0, 92.508177083),
#  ('Pharaoh Hound', 5.0, 0.43114969135174996),
#  ('Pug-Lhasa Apso Mix', 5.0, 0.24883969908),
#  ('American Foxhound', 5.0, 27.645873199721603),
#  ('Rat Terrier- Mix', 5.0, 0.002181712975),
#  ('Boxer-Jindo Mix', 5.0, 0.32361979169),
#  ('Bolognese', 5.0, 4.793577031750767),
#  ('Staffordshire Bull Terrier-Bullmastiff Mix', 5.0, 0.17230748456370001),
#  ('Boxer-Great Dane Mix', 5.0, 0.022071759276),
#  ('Barbet', 5.0, 6.7219299769),
#  ('Border Collie-Standard Schnauzer Mix', 5.0, 14.235763889),
#  ('Yorkshire Terrier-Soft Coated Wheaten Terrier Mix', 5.0, 0.005613425921),
#  ('Great Dane-Doberman Pinscher Mix', 5.0, 0.0041579861139),
#  ('Giant Schnauzer-Standard Poodle Mix', 5.0, 0.1117696759231),
#  ('Poodle-English Cocker Spaniel Mix', 5.0, 0.24604166669),
#  ('Poodle-Newfoundland Mix', 5.0, 2.0655758102),
#  ('Labrador Retriever-Standard Poodle Mix', 5.0, 0.04377379115793333),
#  ('American Eskimo Dog-Pembroke Welsh Corgi Mix', 5.0, 1.2194618055),
#  ('Border Collie-Icelandic Sheepdog Mix', 5.0, 0.79303530094),
#  ('Bernese Mountain Dog-Chow Chow Mix', 5.0, 0.093706597225),
#  ('Labrador Retriever-Chow Chow Mix', 4.8, 0.00344112655074),
#  ('Chihuahua-Pomeranian Mix', 4.777777777777778, 0.5212751348728221),
#  ('Dachshund-Beagle Mix', 4.75, 0.22722897375409998),
#  ('Saluki', 4.75, 0.016124131953475),
#  ('Rottweiler-German Shepherd Dog Mix', 4.714285714285714, 3.9283319978603783),
#  ('Beagle-Russell Terrier Mix', 4.5, 0.5909909336460499),
#  ('Dachshund-Parson Russell Terrier Mix', 4.5, 0.0022395833330999997),
#  ('German Shepherd Dog-Redbone Coonhound Mix', 4.5, 1.63626543208),
#  ('Bulldog-American Pit Bull Terrier Mix', 4.5, 0.41633198304755004),
#  ('Flat-Coated Retriever-Border Collie Mix', 4.5, 0.00299189814155),
#  ('Belgian Malinois-Dutch Shepherd Mix', 4.5, 0.047698495362049995),
#  ('Poodle-German Shepherd Dog Mix', 4.5, 0.1690171682071),
#  ('Anatolian Shepherd Dog-Great Pyrenees Mix', 4.5, 0.0042361111329),
#  ('Standard Poodle-Golden Retriever Mix', 4.5, 1.0064419367367998),
#  ('Chihuahua-Jack Russell Terrier Mix', 4.5, 1.8674754050632998),
#  ('Jack Russell Terrier-Rat Terrier Mix', 4.5, 0.25663628472764),
#  ('German Shepherd Dog-Norwegian Elkhound Mix', 4.5, 0.34569830247059996),
#  ('German Shorthaired Pointer-Pointer Mix', 4.5, 2.17399112659275),
#  ('Border Collie-Bluetick Coonhound Mix', 4.5, 0.0051909722088),
#  ('Boxer-German Shepherd Dog Mix', 4.333333333333333, 0.0033455503936333335),
#  ('Basset Hound-Labrador Retriever Mix', 4.333333333333333, 0.8696096964774666),
#  ('Miniature Schnauzer-Yorkshire Terrier Mix', 4.333333333333333, 0.09843786744233333),
#  ('Parson Russell Terrier-Beagle Mix', 4.0, 0.0020640432297),
#  ('Russell Terrier-Pug Mix', 4.0, 8.3206790123),
#  ('Bulldog-Beagle Mix', 4.0, 0.0024035493837),
#  ('Russell Terrier-Chihuahua Mix', 4.0, 0.00224922838),
#  ('American Staffordshire Terrier-Catahoula Leopard Dog Mix', 4.0, 0.0035686728461),
#  ('Whippet-Chinese Shar-Pei Mix', 4.0, 0.00273148149),
#  ('Labrador Retriever-Basset Hound Mix', 4.0, 0.0026311728084),
#  ('Poodle-Standard Schnauzer Mix', 4.0, 0.6056423611063501),
#  ('Boxer-Bloodhound Mix', 4.0, 0.0024768518443),
#  ('Australian Shepherd-Chow Chow Mix', 4.0, 0.0032407407417),
#  ('Pembroke Welsh Corgi-American Eskimo Dog Mix', 4.0, 0.0029359567751),
#  ('English Cocker Spaniel-Poodle Mix', 4.0, 0.0025925926171),
#  ('Border Collie- Mix', 4.0, 0.0026543209674000003),
#  ('Shiba Inu-Pembroke Welsh Corgi Mix', 4.0, 0.0043518518405),
#  ('Papillon-Japanese Chin Mix', 4.0, 0.0057484567703),
#  ('Russell Terrier-Poodle Mix', 4.0, 0.23526620372),
#  ('Italian Greyhound-Cardigan Welsh Corgi Mix', 4.0, 0.0021874999699),
#  ('Maltese-Cocker Spaniel Mix', 4.0, 0.0021412036924),
#  ('-Australian Cattle Dog Mix', 4.0, 0.003368055565),
#  ('Bloodhound-Irish Setter Mix', 4.0, 0.0021990740986),
#  ('Maltese-Standard Schnauzer Mix', 4.0, 0.0032368826991),
#  ('Papillon-Poodle Mix', 4.0, 0.0025347222486),
#  ('Boxer-Russell Terrier Mix', 4.0, 0.0036149691245),
#  ('Chihuahua-Shiba Inu Mix', 4.0, 0.00268904321555),
#  ('German Shepherd Dog- Mix', 4.0, 0.006159979436299999),
#  ('Beagle-Pointer Mix', 4.0, 0.001516203667),
#  ('Border Collie-American Eskimo Dog Mix', 4.0, 0.0019791666808),
#  ('Whippet-Russell Terrier Mix', 4.0, 9.2218479938),
#  ('Pomeranian-Chihuahua Mix', 4.0, 0.0444610339556),
#  ('Boxer-Greyhound Mix', 4.0, 0.0028510802262),
#  ('German Shepherd Dog-Mastiff Mix', 4.0, 0.002056327184),
#  ('Rhodesian Ridgeback-Redbone Coonhound Mix', 4.0, 5.0055787037),
#  ('Catahoula Leopard Dog-American Pit Bull Terrier Mix', 4.0, 0.0033526234323),
#  ...]

# %% [markdown]
# **Question 5: Write a query that outputs the average amount of time it took customers to complete each type of test where any individual reaction times over 6000 hours are excluded and only average reaction times that are greater than 0 seconds are included (your output should end up with 67 rows).**

# %%
# %%sql
# SELECT test_name, AVG(TIMESTAMPDIFF(HOUR, start_time, end_time)) AS "Average duration"
# FROM exam_answers
# WHERE TIMESTAMPDIFF(MINUTE, start_time, end_time) < 6000
# GROUP BY test_name
# HAVING AVG(TIMESTAMPDIFF(HOUR, start_time, end_time)) > 0
# Out:
# 58 rows affected.
# [('Activity', Decimal('0.5096')),
#  ('Arm Pointing', Decimal('0.0238')),
#  ('Attachment', Decimal('0.0381')),
#  ('Confinement', Decimal('0.1757')),
#  ('Cover Your Eyes', Decimal('0.0555')),
#  ('Delayed Cup Game', Decimal('0.0158')),
#  ('Diet', Decimal('0.6735')),
#  ('Different Perspective', Decimal('0.0493')),
#  ('Emotions', Decimal('0.1173')),
#  ('Environment', Decimal('0.0779')),
#  ('Excitability', Decimal('0.0263')),
#  ('Eye Contact Game', Decimal('0.0738')),
#  ('Eye Contact Warm-up', Decimal('0.0513')),
#  ('Foot Pointing', Decimal('0.0281')),
#  ('Gender', Decimal('0.0882')),
#  ('Impossible Task Game', Decimal('0.0238')),
#  ('Impossible Task Warm-up', Decimal('0.1040')),
#  ('Inferential Reasoning Game', Decimal('0.0157')),
#  ('Inferential Reasoning Warm-up', Decimal('0.0336')),
#  ('Memory versus Pointing', Decimal('0.0057')),
#  ('Memory versus Smell', Decimal('0.0235')),
#  ('Navigation Game', Decimal('0.1273')),
#  ('Navigation Learning', Decimal('0.0226')),
#  ('Navigation Warm-up', Decimal('0.1637')),
#  ('Numerosity Warm-Up', Decimal('0.0116')),
#  ('Obedience', Decimal('0.0169')),
#  ('One Cup Warm-up', Decimal('0.0472')),
#  ('Owner', Decimal('0.0567')),
#  ('Partnership', Decimal('0.0244')),
#  ('Perception', Decimal('0.0339')),
#  ('Physical', Decimal('0.1232')),
#  ('Physical Reasoning Game', Decimal('0.0065')),
#  ('Physical Reasoning Warm-up', Decimal('0.0351')),
#  ('Purina', Decimal('0.0327')),
#  ('Purina-Only', Decimal('0.0430')),
#  ('Puzzles', Decimal('0.0310')),
#  ('Recall', Decimal('0.0296')),
#  ('Set 1', Decimal('0.0790')),
#  ('Set 2', Decimal('0.1259')),
#  ('Set 3', Decimal('0.2641')),
#  ('Shaker Warm-Up', Decimal('0.0644')),
#  ('Shy/Boldness', Decimal('0.0436')),
#  ('Sociability', Decimal('0.3241')),
#  ('Social', Decimal('0.7465')),
#  ('Social-Quiz', Decimal('2.3382')),
#  ('Stair Game', Decimal('0.0793')),
#  ('Surprise And Delight', Decimal('0.2592')),
#  ('Switch', Decimal('0.0531')),
#  ('Toys', Decimal('0.0521')),
#  ('Training', Decimal('0.0550')),
#  ('Treat Warm-up', Decimal('0.0601')),
#  ('Turn Your Back', Decimal('0.0759')),
#  ('Two Cup Warm-up', Decimal('0.0086')),
#  ('Warm-Up', Decimal('0.0486')),
#  ('Watching', Decimal('0.2822')),
#  ('Watching - Part 2', Decimal('0.0834')),
#  ('Yawn Game', Decimal('0.1556')),
#  ('Yawn Warm-up', Decimal('0.5921'))]

# %% [markdown]
# **Question 6: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code (postal code) in the United States, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state should be AE and there should be 5043 rows in total in your output).**

# %%
# %%sql
# SELECT state, zip, COUNT(DISTINCT user_guid) AS Total
# FROM users
# GROUP BY 1, 2
# ORDER BY 1 ASC, 3 DESC
# Out:
# 6140 rows affected.
# [(None, None, 16932),
#  ('0', '1006', 2),
#  ('0', 'TD5 7PD', 1),
#  ('0', '2577', 1),
#  ('0', 'TS18 5AW', 1),
#  ('0', '2820', 1),
#  ('0', 'W8 5TT', 1),
#  ('0', '3000', 1),
#  ('0', '3141', 1),
#  ('0', '3226', 1),
#  ('0', '3930', 1),
#  ('0', '4179', 1),
#  ('0', '45993', 1),
#  ('0', '48683', 1),
#  ('0', '5073', 1),
#  ('0', '728', 1),
#  ('0', '7300-569, Urra', 1),
#  ('0', '7600', 1),
#  ('0', '823172', 1),
#  ('0', '82343', 1),
#  ('0', '919', 1),
#  ('0', '93162', 1),
#  ('0', 'BN27 2JJ', 1),
#  ('0', 'BN3 3EB', 1),
#  ('0', 'DE127JD', 1),
#  ('0', 'E17 9PA', 1),
#  ('0', 'FLBX', 1),
#  ('0', 'FY3 8FJ', 1),
#  ('0', 'G13 2TL', 1),
#  ('0', 'GU17 9DX', 1),
#  ('0', '0000AA', 1),
#  ('0', 'IM9 6TA', 1),
#  ('0', 'M171WF', 1),
#  ('0', '100125', 1),
#  ('0', 'ME14 2QY', 1),
#  ('0', 'None', 1),
#  ('0', '10616', 1),
#  ('0', 'OX25 5PP', 1),
#  ('0', '1108', 1),
#  ('0', 'OX29 8JB', 1),
#  ('0', '21600', 1),
#  ('0', 'SG5 2TQ', 1),
#  ('0', '2259', 1),
#  ('1', '110', 1),
#  ('1', '11103', 1),
#  ('1', '1259', 1),
#  ('1', '1455', 1),
#  ('1', '169588', 1),
#  ('1', '249081', 1),
#  ('1', '310206', 1),
#  ('1', '358459', 1),
#  ('1', '470717', 1),
#  ('1', '5136', 1),
#  ('1', '520124', 1),
#  ('1', '545571', 1),
#  ('1', '550525', 1),
#  ('1', '560103', 1),
#  ('1', '656', 1),
#  ('1', '69046', 1),
#  ('1', '760809', 1),
#  ('10', '4700', 1),
#  ('102', '4240', 1),
#  ('11', '2790-021', 1),
#  ('11', '4352', 1),
#  ('12', '273-0012', 1),
#  ('12', '5355', 1),
#  ('13', '1540001', 1),
#  ('13', '4460-070', 1),
#  ('16', '7011', 1),
#  ('16', '81000', 1),
#  ('18', '8300', 1),
#  ('19', '9018', 1),
#  ('2', '1349', 1),
#  ('2', '1353', 1),
#  ('2', '1362', 1),
#  ('2', '1369', 1),
#  ('2', '1430', 1),
#  ('2', '1550', 1),
#  ('2', '760647', 1),
#  ('2', '760805', 1),
#  ('2', '760867', 1),
#  ('21', '10126', 2),
#  ('21', '10000', 1),
#  ('21', '10122', 1),
#  ('22', '1618', 1),
#  ('25', '20123', 1),
#  ('25', '20124', 1),
#  ('25', '24124', 1),
#  ('3', '168', 1),
#  ('3', '2734', 1),
#  ('3', '3107', 1),
#  ('3', '485', 1),
#  ('3', '489', 1),
#  ('3', '566', 1),
#  ('3', '574', 1),
#  ('3', '578', 1),
#  ('3', '754', 1),
#  ('3', '763', 1),
#  ('3', '874', 1),
#  ('31', '200031', 1),
#  ('32', '3039', 1),
#  ('34', '37138', 1),
#  ('36', '34141', 1),
#  ('36', '34011', 1),
#  ('37', '10129', 1),
#  ('37', '10614', 1),
#  ('37', '10912', 1),
#  ('37', '11912', 1),
#  ('37', '12112', 1),
#  ('37', '13516', 1),
#  ('37', '13519', 1),
#  ('37', '50410', 1),
#  ('37', '74017', 1),
#  ('37', '76311', 1),
#  ('4', '2365', 1),
#  ('4', '31311', 1),
#  ('4', '4600', 1),
#  ('42', '17100', 1),
#  ('44', '510000', 1),
#  ('45', '44121', 1),
#  ('45', '47522', 1),
#  ('45', '48123', 1),
#  ('5', '600051', 1),
#  ('52', '58017', 1),
#  ('57', '62026', 1),
#  ('6', '3014', 1),
#  ('6', '3043', 1),
#  ('6', '6540', 1),
#  ('61', '1000', 1),
#  ('62', '100', 1),
#  ('62', '176', 1),
#  ('62', '68', 1),
#  ('65', '26022', 1),
#  ('65', 'Italy', 1),
#  ('7', 'AD400', 1),
#  ('7', '3070', 1),
#  ('75', '70020', 1),
#  ('78', '50108', 1),
#  ('78', '51008', 1),
#  ('78', '61601', 1),
#  ('8', '3742', 1),
#  ('81', '9330', 1),
#  ('82', '7800', 2),
#  ('82', '7620', 1),
#  ('82', '8310', 1),
#  ('82', '8362', 1),
#  ('83', '5250', 1),
#  ('83', '5700', 1),
#  ('83', '5953', 1),
#  ('83', '6230', 1),
#  ('83', '6720', 1),
#  ('83', '7120', 1),
#  ('84', '2000', 2),
#  ('84', '2300', 2),
#  ('84', '3140', 1),
#  ('84', '3500', 1),
#  ('84', '8240', 1),
#  ('84', 'DK-2450', 1),
#  ('84', '1171', 1),
#  ('84', '1561', 1),
#  ('84', '1720', 1),
#  ('84', '1874', 1),
#  ('84', '1909', 1),
#  ('84', '2100', 1),
#  ('84', '2200', 1),
#  ('84', '2760', 1),
#  ('84', '2920', 1),
#  ('84', '2960', 1),
#  ('84', '2990', 1),
#  ('84', '3070', 1),
#  ('85', '4180', 1),
#  ('85', '4470', 1),
#  ('88', '9127', 1),
#  ('9', '1210', 1),
#  ('A', '66100', 1),
#  ('A', '68128', 1),
#  ('AB', 'T3A', 3),
#  ('AB', 'T3E', 3),
#  ('AB', 'T3h', 3),
#  ('AB', 'T4C', 3),
#  ('AB', 'T1H', 3),
#  ('AB', 'T6W', 3),
#  ('AB', 'T2J', 3),
#  ('AB', 'T8A', 3),
#  ('AB', 'T2T', 2),
#  ('AB', 'T2Z', 2),
#  ('AB', 't9h', 2),
#  ('AB', 'T3M', 2),
#  ('AB', 'T3Z', 2),
#  ('AB', 'T5E', 2),
#  ('AB', 't0k', 2),
#  ('AB', 'T5H', 2),
#  ('AB', 'T1A', 2),
#  ('AB', 'T6H', 2),
#  ('AB', 'T6J', 2),
#  ('AB', 'T2A', 2),
#  ('AB', 'T6V', 2),
#  ('AB', 'T6X', 2),
#  ('AB', 'T2G', 2),
#  ('AB', 'T8H', 1),
#  ('AB', 't2p', 1),
#  ('AB', 'T8L', 1),
#  ('AB', 'T2S', 1),
#  ('AB', 'T8N', 1),
#  ('AB', 'T8w', 1),
#  ('AB', 'T2W', 1),
#  ('AB', 'T8X', 1),
#  ('AB', 'T9G', 1),
#  ('AB', 'T3G', 1),
#  ('AB', 'T3L', 1),
#  ('AB', '11523', 1),
#  ('AB', '18141', 1),
#  ('AB', '18492', 1),
#  ('AB', 'T5C', 1),
#  ('AB', 'T0A', 1),
#  ('AB', 'T5G', 1),
#  ('AB', 'T0L', 1),
#  ('AB', 'T0M', 1),
#  ('AB', 'T5P', 1),
#  ('AB', 'T5W', 1),
#  ('AB', 'T1G', 1),
#  ('AB', 'T5Z', 1),
#  ('AB', 'T6A', 1),
#  ('AB', 'T1J', 1),
#  ('AB', 'T1L', 1),
#  ('AB', 'T1P', 1),
#  ('AB', 'T6M', 1),
#  ('AB', 'T1S', 1),
#  ('AB', 'T6R', 1),
#  ('AB', 'T1V', 1),
#  ('AB', 't6t', 1),
#  ('AB', 'T2C', 1),
#  ('AB', 'T2e', 1),
#  ('AB', 'T7X', 1),
#  ('AB', 't2k', 1),
#  ('AB', 'T8E', 1),
#  ('AB', 'T2N', 1),
#  ('ABD', 'Ab228fr', 1),
#  ('ABD', 'DD11 2BU', 1),
#  ('ABD', 'HU5 3HR', 1),
#  ('ABD', 'N/A', 1),
#  ('ABD', 'SP3 6NY', 1),
#  ('ABD', 'SS14 2QX', 1),
#  ('ABE', 'AB15 9HB', 1),
#  ('AC', '88062-200', 1),
#  ('ACT', '2614', 2),
#  ('ACT', '2582', 1),
#  ('ACT', '2906', 1),
#  ('ACT', '2914', 1),
#  ('ACT', '3056', 1),
#  ('ACT', '3850', 1),
#  ('ACT', '6003', 1),
#  ('ACT', '6159', 1),
#  ('AE', '9128', 2),
#  ('AE', '9053', 1),
#  ('AE', '9107', 1),
#  ('AE', '9469', 1),
#  ('AE', '9845', 1),
#  ('AG', '5034', 1),
#  ('AG', '8916', 1),
#  ('AG', 'N/A', 1),
#  ('AGB', 'PA28 6DD', 1),
#  ('AK', '99507', 3),
#  ('AK', '99709', 3),
#  ('AK', '99501', 2),
#  ('AK', '99577', 2),
#  ('AK', '99502', 1),
#  ('AK', '99509', 1),
#  ('AK', '99516', 1),
#  ('AK', '99518', 1),
#  ('AK', '99567', 1),
#  ('AK', '99587', 1),
#  ('AK', '99611', 1),
#  ('AK', '99645', 1),
#  ('AK', '99676', 1),
#  ('AK', '99705', 1),
#  ('AK', '99712', 1),
#  ('AK', '99752', 1),
#  ('AK', '99775', 1),
#  ('AK', '99824', 1),
#  ('AK', '99928', 1),
#  ('AL', '35209', 4),
#  ('AL', '35801', 2),
#  ('AL', '36116', 2),
#  ('AL', '36532', 2),
#  ('AL', '36609', 2),
#  ('AL', '35662', 1),
#  ('AL', '35674', 1),
#  ('AL', '35758', 1),
#  ('AL', '35760', 1),
#  ('AL', '35763', 1),
#  ('AL', '35803', 1),
#  ('AL', '35906', 1),
#  ('AL', '35976', 1),
#  ('AL', '36037', 1),
#  ('AL', '36104', 1),
#  ('AL', '36106', 1),
#  ('AL', '36203', 1),
#  ('AL', '36303', 1),
#  ('AL', '36375', 1),
#  ('AL', '36527', 1),
#  ('AL', '36561', 1),
#  ('AL', '36602', 1),
#  ('AL', '36604', 1),
#  ('AL', '35004', 1),
#  ('AL', '35007', 1),
#  ('AL', '36695', 1),
#  ('AL', '35094', 1),
#  ('AL', '36801', 1),
#  ('AL', '35121', 1),
#  ('AL', '36832', 1),
#  ('AL', '35179', 1),
#  ('AL', '35205', 1),
#  ('AL', '35216', 1),
#  ('AL', '35242', 1),
#  ('AL', '35405', 1),
#  ('AL', '35476', 1),
#  ('AL', '35646', 1),
#  ('ALM', '50013', 1),
#  ('AN', '29604', 1),
#  ('AN', '29649', 1),
#  ('AN', '29680', 1),
#  ('ANT', '54', 1),
#  ('ANT', 'BT38 8DF', 1),
#  ('AP', '96310', 1),
#  ('AP', '96367', 1),
#  ('AP', '96377', 1),
#  ('AP', '96205', 1),
#  ('AR', '72207', 3),
#  ('AR', '72401', 3),
#  ('AR', '72223', 2),
#  ('AR', '72632', 2),
#  ('AR', '72712', 2),
#  ('AR', '72956', 1),
#  ('AR', '71909', 1),
#  ('AR', '71913', 1),
#  ('AR', '72015', 1),
#  ('AR', '72034', 1),
#  ('AR', '72042', 1),
#  ('AR', '72058', 1),
#  ('AR', '72113', 1),
#  ('AR', '72135', 1),
#  ('AR', '72201', 1),
#  ('AR', '72202', 1),
#  ('AR', '72206', 1),
#  ('AR', '72212', 1),
#  ('AR', '72554', 1),
#  ('AR', '72631', 1),
#  ('AR', '72701', 1),
#  ('AR', '72703', 1),
#  ('AR', '72704', 1),
#  ('AR', '72714', 1),
#  ('AR', '72756', 1),
#  ('AR', '72762', 1),
#  ('AR', '72802', 1),
#  ('AR', '72901', 1),
#  ('AR', '72908', 1),
#  ('AS', '33500', 1),
#  ('AS', '33610', 1),
#  ('AZ', '86303', 14),
#  ('AZ', '85718', 6),
#  ('AZ', '85749', 5),
#  ('AZ', '85253', 5),
#  ('AZ', '85254', 5),
#  ('AZ', '85260', 5),
#  ('AZ', '85711', 5),
#  ('AZ', '85750', 4),
#  ('AZ', 'N/A', 4),
#  ('AZ', '85266', 4),
#  ('AZ', '85716', 4),
#  ('AZ', '85719', 4),
#  ('AZ', '86305', 3),
#  ('AZ', '85233', 3),
#  ('AZ', '85021', 3),
#  ('AZ', '85392', 3),
#  ('AZ', '85022', 3),
#  ('AZ', '85250', 3),
#  ('AZ', '85032', 3),
#  ('AZ', '85042', 3),
#  ('AZ', '85255', 3),
#  ('AZ', '85044', 3),
#  ('AZ', '85257', 3),
#  ('AZ', '85048', 3),
#  ('AZ', '85282', 3),
#  ('AZ', '85283', 3),
#  ('AZ', '85296', 3),
#  ('AZ', '85737', 3),
#  ('AZ', '85739', 2),
#  ('AZ', '85304', 2),
#  ('AZ', '85143', 2),
#  ('AZ', '85202', 2),
#  ('AZ', '85745', 2),
#  ('AZ', '85203', 2),
#  ('AZ', '85748', 2),
#  ('AZ', '85206', 2),
#  ('AZ', '85374', 2),
#  ('AZ', '85024', 2),
#  ('AZ', '85615', 2),
#  ('AZ', '85028', 2),
#  ('AZ', '85251', 2),
#  ('AZ', '86351', 2),
#  ('AZ', '85045', 2),
#  ('AZ', '85259', 2),
#  ('AZ', '85704', 2),
#  ('AZ', '85086', 2),
#  ('AZ', '85712', 2),
#  ('AZ', '85281', 2),
#  ('AZ', '85715', 2),
#  ('AZ', '85303', 1),
#  ('AZ', '85140', 1),
#  ('AZ', '85743', 1),
#  ('AZ', '85308', 1),
#  ('AZ', '85327', 1),
#  ('AZ', '129188', 1),
#  ('AZ', '85335', 1),
#  ('AZ', '85205', 1),
#  ('AZ', '85006', 1),
#  ('AZ', '85338', 1),
#  ('AZ', '85008', 1),
#  ('AZ', '85755', 1),
#  ('AZ', '85340', 1),
#  ('AZ', '85207', 1),
#  ('AZ', '85012', 1),
#  ('AZ', '86002', 1),
#  ('AZ', '85353', 1),
#  ('AZ', '85209', 1),
#  ('AZ', '85013', 1),
#  ('AZ', '86301', 1),
#  ('AZ', '85365', 1),
#  ('AZ', '85210', 1),
#  ('AZ', '85015', 1),
#  ('AZ', '85212', 1),
#  ('AZ', '85016', 1),
#  ('AZ', '85382', 1),
#  ('AZ', '85226', 1),
#  ('AZ', '85020', 1),
#  ('AZ', '86312', 1),
#  ('AZ', '85385', 1),
#  ('AZ', '86314', 1),
#  ('AZ', '85248', 1),
#  ('AZ', '86323', 1),
#  ('AZ', '85614', 1),
#  ('AZ', '85249', 1),
#  ('AZ', '86326', 1),
#  ('AZ', '85027', 1),
#  ('AZ', '86327', 1),
#  ('AZ', '85622', 1),
#  ('AZ', '85029', 1),
#  ('AZ', '86336', 1),
#  ('AZ', '85635', 1),
#  ('AZ', '85636', 1),
#  ('AZ', '86403', 1),
#  ('AZ', '85641', 1),
#  ('AZ', '86426', 1),
#  ('AZ', '85646', 1),
#  ('AZ', '86504', 1),
#  ('AZ', '85650', 1),
#  ('AZ', '85658', 1),
#  ('AZ', '85050', 1),
#  ('AZ', '85262', 1),
#  ('AZ', '85069', 1),
#  ('AZ', '85710', 1),
#  ('AZ', '85083', 1),
#  ('AZ', '85268', 1),
#  ('AZ', '85118', 1),
#  ('AZ', '85119', 1),
#  ('AZ', '85120', 1),
#  ('AZ', '85284', 1),
#  ('AZ', '85122', 1),
#  ('AZ', '85286', 1),
#  ('AZ', '85128', 1),
#  ('AZ', '85730', 1),
#  ('AZ', '85138', 1),
#  ('B', '1414', 1),
#  ('B', '33610', 1),
#  ('B', '54248', 1),
#  ('B', '54641', 1),
#  ('B', '60463', 1),
#  ('B', 'C1244AAK', 1),
#  ('B', 'N/A', 1),
#  ('BAS', 'Ba2 5nz', 1),
#  ('BB', '10405', 1),
#  ('BB', '37520', 1),
#  ('BC', 'V0R', 5),
#  ('BC', 'V0N', 4),
#  ('BC', 'V5V', 4),
#  ('BC', 'V5L', 3),
#  ('BC', 'V6B', 3),
#  ('BC', 'V6K', 3),
#  ('BC', 'V8P', 3),
#  ('BC', 'V3S', 3),
#  ('BC', 'V9K', 3),
#  ('BC', 'V9T', 2),
#  ('BC', 'V0E', 2),
#  ('BC', 'V0G', 2),
#  ('BC', 'V5T', 2),
#  ('BC', 'V1H', 2),
#  ('BC', 'v1m', 2),
#  ('BC', 'V6G', 2),
#  ('BC', 'V2E', 2),
#  ('BC', 'V2K', 2),
#  ('BC', 'V2M', 2),
#  ('BC', 'V3h', 2),
#  ('BC', 'V8T', 2),
#  ('BC', 'V4a', 2),
#  ('BC', 'V9A', 2),
#  ('BC', 'V4l', 2),
#  ('BC', 'V9N', 2),
#  ('BC', 'v9r', 1),
#  ('BC', 'V4V', 1),
#  ('BC', 'N/A', 1),
#  ('BC', 'V5A', 1),
#  ('BC', 'V0A', 1),
#  ('BC', 'V5C', 1),
#  ('BC', 'V0C', 1),
#  ('BC', 'V5e', 1),
#  ('BC', 'V5N', 1),
#  ('BC', 'V0H', 1),
#  ('BC', 'V5P', 1),
#  ('BC', 'v5w', 1),
#  ('BC', 'V5X', 1),
#  ('BC', 'V1N', 1),
#  ('BC', 'V5Z', 1),
#  ('BC', 'v1w', 1),
#  ('BC', 'V2A', 1),
#  ('BC', 'V2J', 1),
#  ('BC', 'V6N', 1),
#  ('BC', 'V6R', 1),
#  ('BC', 'V6Z', 1),
#  ('BC', 'V2R', 1),
#  ('BC', 'V7E', 1),
#  ('BC', 'V2T', 1),
#  ('BC', 'V7H', 1),
#  ('BC', 'V7M', 1),
#  ('BC', 'V3J', 1),
#  ('BC', 'V7R', 1),
#  ('BC', 'V3L', 1),
#  ('BC', 'V7V', 1),
#  ('BC', 'V3N', 1),
#  ('BC', 'v8r', 1),
#  ('BC', 'v3t', 1),
#  ('BC', 'V8Z', 1),
#  ('BC', 'v4e', 1),
#  ('BC', 'V9c', 1),
#  ('BC', 'V4M', 1),
#  ('BC', 'V9M', 1),
#  ('BC', 'V4R', 1),
#  ('BC', 'V4T', 1),
#  ('BE', '10115', 1),
#  ('BE', '10119', 1),
#  ('BE', '10437', 1),
#  ('BE', '10439', 1),
#  ('BE', '10827', 1),
#  ('BE', '3007', 1),
#  ('BE', '3600', 1),
#  ('BE', 'Berlin', 1),
#  ('BI', '4030000', 1),
#  ('BI', '4130000', 1),
#  ('BIR', 'B15 2HR', 1),
#  ('BK', '6000', 1),
#  ('BNE', 'N29DX', 1),
#  ('BOL', '0', 1),
#  ('BP', 'EE15235', 1),
#  ('BRC', 'RG12 0XX', 1),
#  ('BRU', '1080', 1),
#  ('BS', '4125', 1),
#  ('BST', 'BS3 4TL', 1),
#  ('BU', '1085', 1),
#  ('BU', '1158', 1),
#  ('BW', '68723', 1),
#  ('BW', '68799', 1),
#  ('BW', '69226', 1),
#  ('BW', '78224', 1),
#  ('BW', '79111', 1),
#  ('BY', '85551', 1),
#  ('BY', '95236', 1),
#  ('BY', '80339', 1),
#  ('BY', '81379', 1),
#  ('BY', '81827', 1),
#  ('BY', '83083', 1),
#  ('C', '0', 1),
#  ('C', 'C1004AAN', 1),
#  ('CA', '92107', 16),
#  ('CA', '90046', 13),
#  ('CA', '94107', 12),
#  ('CA', '92130', 12),
#  ('CA', '94110', 10),
#  ('CA', '92024', 10),
#  ('CA', '94114', 9),
#  ('CA', '94941', 9),
#  ('CA', '94025', 9),
#  ('CA', '94611', 9),
#  ('CA', '90068', 8),
#  ('CA', '90069', 8),
#  ('CA', '94131', 8),
#  ('CA', '92064', 8),
#  ('CA', '90049', 8),
#  ('CA', '90803', 7),
#  ('CA', '93003', 7),
#  ('CA', '94117', 7),
#  ('CA', '94121', 7),
#  ('CA', '90266', 7),
#  ('CA', '90278', 7),
#  ('CA', '94602', 7),
#  ('CA', '90291', 7),
#  ('CA', '90292', 7),
#  ('CA', '91301', 6),
#  ('CA', '92103', 6),
#  ('CA', '94901', 6),
#  ('CA', '94903', 6),
#  ('CA', '92672', 6),
#  ('CA', '94123', 6),
#  ('CA', '90274', 6),
#  ('CA', '94952', 6),
#  ('CA', '90277', 6),
#  ('CA', '90036', 6),
#  ('CA', '94549', 6),
#  ('CA', '90039', 6),
#  ('CA', '94061', 6),
#  ('CA', '95762', 6),
#  ('CA', '92071', 6),
#  ('CA', '95008', 6),
#  ('CA', '95014', 6),
#  ('CA', '92009', 5),
#  ('CA', '94706', 5),
#  ('CA', '92101', 5),
#  ('CA', '94510', 5),
#  ('CA', '94109', 5),
#  ('CA', '93940', 5),
#  ('CA', '92106', 5),
#  ('CA', '94904', 5),
#  ('CA', '90210', 5),
#  ('CA', '94118', 5),
#  ('CA', '93012', 5),
#  ('CA', '90232', 5),
#  ('CA', '93023', 5),
#  ('CA', '90025', 5),
#  ('CA', '94597', 5),
#  ('CA', '92122', 5),
#  ('CA', '93105', 5),
#  ('CA', '94040', 5),
#  ('CA', '95476', 5),
#  ('CA', '94550', 5),
#  ('CA', '91406', 5),
#  ('CA', '95003', 5),
#  ('CA', '92211', 5),
#  ('CA', '90405', 5),
#  ('CA', '95818', 5),
#  ('CA', '90720', 4),
#  ('CA', '95608', 4),
#  ('CA', '95616', 4),
#  ('CA', '91307', 4),
#  ('CA', '90004', 4),
#  ('CA', '92649', 4),
#  ('CA', '95401', 4),
#  ('CA', '92886', 4),
#  ('CA', '95403', 4),
#  ('CA', '91320', 4),
#  ('CA', '95404', 4),
#  ('CA', '92656', 4),
#  ('CA', '92109', 4),
#  ('CA', '90211', 4),
#  ('CA', '94523', 4),
#  ('CA', '94583', 4),
#  ('CA', '90212', 4),
#  ('CA', '92026', 4),
#  ('CA', '95407', 4),
#  ('CA', '92660', 4),
#  ('CA', '92116', 4),
#  ('CA', '94127', 4),
#  ('CA', '92117', 4),
#  ('CA', '90265', 4),
#  ('CA', '92677', 4),
#  ('CA', '90026', 4),
#  ('CA', '90027', 4),
#  ('CA', '93103', 4),
#  ('CA', '91367', 4),
#  ('CA', '91030', 4),
#  ('CA', '95472', 4),
#  ('CA', '90034', 4),
#  ('CA', '92126', 4),
#  ('CA', '93561', 4),
#  ('CA', '95125', 4),
#  ('CA', '94965', 4),
#  ('CA', '92128', 4),
#  ('CA', '94306', 4),
#  ('CA', '92067', 4),
#  ('CA', '94062', 4),
#  ('CA', '94403', 4),
#  ('CA', '92612', 4),
#  ('CA', '91941', 4),
#  ('CA', '90404', 4),
#  ('CA', '91942', 4),
#  ('CA', '94501', 4),
#  ('CA', '92078', 4),
#  ('CA', '94558', 4),
#  ('CA', '94703', 4),
#  ('CA', '94506', 4),
#  ('CA', '94705', 3),
#  ('CA', '90065', 3),
#  ('CA', '92629', 3),
#  ('CA', '92867', 3),
#  ('CA', '93907', 3),
#  ('CA', '90731', 3),
#  ('CA', '92646', 3),
#  ('CA', '94568', 3),
#  ('CA', '95032', 3),
#  ('CA', '95618', 3),
#  ('CA', '92019', 3),
#  ('CA', '91311', 3),
#  ('CA', '93924', 3),
#  ('CA', '95926', 3),
#  ('CA', '94115', 3),
#  ('CA', '95621', 3),
#  ('CA', '95051', 3),
#  ('CA', '91321', 3),
#  ('CA', '93955', 3),
#  ('CA', '90807', 3),
#  ('CA', '94002', 3),
#  ('CA', '95630', 3),
#  ('CA', '95062', 3),
#  ('CA', '94010', 3),
#  ('CA', '94928', 3),
#  ('CA', '92111', 3),
#  ('CA', '92115', 3),
#  ('CA', '95648', 3),
#  ('CA', '92037', 3),
#  ('CA', '93035', 3),
#  ('CA', '94536', 3),
#  ('CA', '90024', 3),
#  ('CA', '91001', 3),
#  ('CA', '93041', 3),
#  ('CA', '95448', 3),
#  ('CA', '91786', 3),
#  ('CA', '92562', 3),
#  ('CA', '94949', 3),
#  ('CA', '95682', 3),
#  ('CA', '93065', 3),
#  ('CA', '91364', 3),
#  ('CA', '93546', 3),
#  ('CA', '94598', 3),
#  ('CA', '92056', 3),
#  ('CA', '92691', 3),
#  ('CA', '92592', 3),
#  ('CA', '94027', 3),
#  ('CA', '92057', 3),
#  ('CA', '91403', 3),
#  ('CA', '91101', 3),
#  ('CA', '92603', 3),
#  ('CA', '94607', 3),
#  ('CA', '95492', 3),
#  ('CA', '92129', 3),
#  ('CA', '94551', 3),
#  ('CA', '94609', 3),
#  ('CA', '92131', 3),
#  ('CA', '93230', 3),
#  ('CA', '90403', 3),
#  ('CA', '95136', 3),
#  ('CA', '92618', 3),
#  ('CA', '94618', 3),
#  ('CA', '94619', 3),
#  ('CA', '93711', 3),
#  ('CA', '92081', 3),
#  ('CA', '95819', 3),
#  ('CA', '92084', 3),
#  ('CA', '91208', 3),
#  ('CA', '94563', 3),
#  ('CA', '90064', 3),
#  ('CA', '92008', 3),
#  ('CA', '94564', 2),
#  ('CA', '94507', 2),
#  ('CA', '91606', 2),
#  ('CA', '90066', 2),
#  ('CA', '92010', 2),
#  ('CA', '91607', 2),
#  ('CA', '91302', 2),
#  ('CA', '94707', 2),
#  ('CA', '95835', 2),
#  ('CA', '93401', 2),
#  ('CA', '94566', 2),
#  ('CA', '94515', 2),
#  ('CA', '95030', 2),
#  ('CA', '93908', 2),
#  ('CA', '95843', 2),
#  ('CA', '93402', 2),
#  ('CA', '92014', 2),
#  ('CA', '92647', 2),
#  ('CA', '95033', 2),
#  ('CA', '92270', 2),
#  ('CA', '93923', 2),
#  ('CA', '90755', 2),
#  ('CA', '92104', 2),
#  ('CA', '92880', 2),
#  ('CA', '94519', 2),
#  ('CA', '95620', 2),
#  ('CA', '92020', 2),
#  ('CA', '92881', 2),
#  ('CA', '91730', 2),
#  ('CA', '93422', 2),
#  ('CA', '94521', 2),
#  ('CA', '90012', 2),
#  ('CA', '92653', 2),
#  ('CA', '94116', 2),
#  ('CA', '92373', 2),
#  ('CA', '94920', 2),
#  ('CA', '95959', 2),
#  ('CA', '94582', 2),
#  ('CA', '93010', 2),
#  ('CA', '92657', 2),
#  ('CA', '90808', 2),
#  ('CA', '92110', 2),
#  ('CA', '93444', 2),
#  ('CA', '94526', 2),
#  ('CA', '93013', 2),
#  ('CA', '95409', 2),
#  ('CA', '95065', 2),
#  ('CA', '92506', 2),
#  ('CA', '94930', 2),
#  ('CA', '90813', 2),
#  ('CA', '94530', 2),
#  ('CA', '95070', 2),
#  ('CA', '91335', 2),
#  ('CA', '94939', 2),
#  ('CA', '92673', 2),
#  ('CA', '91354', 2),
#  ('CA', '94015', 2),
#  ('CA', '96022', 2),
#  ('CA', '90815', 2),
#  ('CA', '94534', 2),
#  ('CA', '95437', 2),
#  ('CA', '93036', 2),
#  ('CA', '94129', 2),
#  ('CA', '95110', 2),
#  ('CA', '91355', 2),
#  ('CA', '95678', 2),
#  ('CA', '95112', 2),
#  ('CA', '94022', 2),
#  ('CA', '90272', 2),
#  ('CA', '93063', 2),
#  ('CA', '94539', 2),
#  ('CA', '94132', 2),
#  ('CA', '94024', 2),
#  ('CA', '92120', 2),
#  ('CA', '93536', 2),
#  ('CA', '92054', 2),
#  ('CA', '95460', 2),
#  ('CA', '94133', 2),
#  ('CA', '90029', 2),
#  ('CA', '94954', 2),
#  ('CA', '92123', 2),
#  ('CA', '95691', 2),
#  ('CA', '94158', 2),
#  ('CA', '92124', 2),
#  ('CA', '92694', 2),
#  ('CA', '94301', 2),
#  ('CA', '91387', 2),
#  ('CA', '94041', 2),
#  ('CA', '94960', 2),
#  ('CA', '93110', 2),
#  ('CA', '95124', 2),
#  ('CA', '96161', 2),
#  ('CA', '95695', 2),
#  ('CA', '95482', 2),
#  ('CA', 'N/A', 2),
#  ('CA', '91104', 2),
#  ('CA', '92065', 2),
#  ('CA', '92606', 2),
#  ('CA', '94608', 2),
#  ('CA', '91105', 2),
#  ('CA', '94610', 2),
#  ('CA', '90402', 2),
#  ('CA', '94553', 2),
#  ('CA', '92780', 2),
#  ('CA', '95134', 2),
#  ('CA', '91423', 2),
#  ('CA', '91106', 2),
#  ('CA', '90045', 2),
#  ('CA', '92782', 2),
#  ('CA', '94070', 2),
#  ('CA', '95005', 2),
#  ('CA', '92075', 2),
#  ('CA', '95816', 2),
#  ('CA', '93291', 2),
#  ('CA', '91945', 2),
#  ('CA', '94502', 2),
#  ('CA', '91502', 2),
#  ('CA', '90503', 2),
#  ('CA', '94559', 2),
#  ('CA', '92003', 2),
#  ('CA', '91505', 2),
#  ('CA', '92626', 2),
#  ('CA', '95010', 2),
#  ('CA', '91207', 2),
#  ('CA', '93308', 2),
#  ('CA', '94505', 2),
#  ('CA', '92627', 2),
#  ('CA', '94089', 2),
#  ('CA', '90638', 2),
#  ('CA', '93309', 2),
#  ('CA', '92835', 2),
#  ('CA', '95354', 2),
#  ('CA', '91604', 2),
#  ('CA', '91214', 1),
#  ('CA', '92253', 1),
#  ('CA', '93726', 1),
#  ('CA', '95833', 1),
#  ('CA', '90704', 1),
#  ('CA', '92092', 1),
#  ('CA', '93311', 1),
#  ('CA', '95605', 1),
#  ('CA', '92865', 1),
#  ('CA', '95355', 1),
#  ('CA', '94103', 1),
#  ('CA', '95020', 1),
#  ('CA', '92260', 1),
#  ('CA', '93730', 1),
#  ('CA', '95834', 1),
#  ('CA', '93312', 1),
#  ('CA', '94565', 1),
#  ('CA', '95356', 1),
#  ('CA', '92637', 1),
#  ('CA', '95023', 1),
#  ('CA', '92262', 1),
#  ('CA', '92102', 1),
#  ('CA', '95610', 1),
#  ('CA', '90067', 1),
#  ('CA', '92011', 1),
#  ('CA', '92869', 1),
#  ('CA', '95361', 1),
#  ('CA', '91701', 1),
#  ('CA', '91303', 1),
#  ('CA', '92263', 1),
#  ('CA', '94708', 1),
#  ('CA', '90740', 1),
#  ('CA', '92870', 1),
#  ('CA', '94518', 1),
#  ('CA', '95366', 1),
#  ('CA', '91702', 1),
#  ('CA', '91711', 1),
#  ('CA', '92648', 1),
#  ('CA', '94112', 1),
#  ('CA', '94709', 1),
#  ('CA', '95864', 1),
#  ('CA', '93405', 1),
#  ('CA', '94571', 1),
#  ('CA', '95383', 1),
#  ('CA', '91723', 1),
#  ('CA', '95037', 1),
#  ('CA', '92307', 1),
#  ('CA', '92105', 1),
#  ('CA', '93420', 1),
#  ('CA', '94574', 1),
#  ('CA', '90071', 1),
#  ('CA', '94520', 1),
#  ('CA', '90005', 1),
#  ('CA', '92651', 1),
#  ('CA', '95046', 1),
#  ('CA', '91316', 1),
#  ('CA', '92320', 1),
#  ('CA', '95945', 1),
#  ('CA', '90804', 1),
#  ('CA', '94577', 1),
#  ('CA', '90077', 1),
#  ('CA', '92021', 1),
#  ('CA', '91737', 1),
#  ('CA', '95050', 1),
#  ('CA', '93953', 1),
#  ('CA', '95949', 1),
#  ('CA', '90806', 1),
#  ('CA', '93428', 1),
#  ('CA', '94580', 1),
#  ('CA', '95624', 1),
#  ('CA', '90014', 1),
#  ('CA', '91748', 1),
#  ('CA', '92374', 1),
#  ('CA', '93443', 1),
#  ('CA', '95628', 1),
#  ('CA', '92025', 1),
#  ('CA', '95405', 1),
#  ('CA', '90015', 1),
#  ('CA', '91750', 1),
#  ('CA', '95060', 1),
#  ('CA', '91324', 1),
#  ('CA', '92503', 1),
#  ('CA', '94925', 1),
#  ('CA', '95965', 1),
#  ('CA', '90016', 1),
#  ('CA', '91755', 1),
#  ('CA', '91325', 1),
#  ('CA', '92504', 1),
#  ('CA', '96001', 1),
#  ('CA', '90810', 1),
#  ('CA', '93446', 1),
#  ('CA', '94585', 1),
#  ('CA', '95633', 1),
#  ('CA', '90230', 1),
#  ('CA', '92027', 1),
#  ('CA', '94528', 1),
#  ('CA', '90017', 1),
#  ('CA', '91764', 1),
#  ...]

# %% [markdown]
# **Question 7: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code in the United States *that have at least 5 users*, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state/ZIP code combination should be AZ/86303).**

# %%
# %%sql
# SELECT state, zip, COUNT(DISTINCT user_guid) AS Total
# FROM users
# GROUP BY 1, 2
# HAVING COUNT(DISTINCT user_guid) >= 5
# ORDER BY 1 ASC, 3 DESC
# Out:
# 289 rows affected.
# [(None, None, 16932),
#  ('AZ', '86303', 14),
#  ('AZ', '85718', 6),
#  ('AZ', '85711', 5),
#  ('AZ', '85749', 5),
#  ('AZ', '85253', 5),
#  ('AZ', '85254', 5),
#  ('AZ', '85260', 5),
#  ('BC', 'V0R', 5),
#  ('CA', '92107', 16),
#  ('CA', '90046', 13),
#  ('CA', '92130', 12),
#  ('CA', '94107', 12),
#  ('CA', '94110', 10),
#  ('CA', '92024', 10),
#  ('CA', '94611', 9),
#  ('CA', '94114', 9),
#  ('CA', '94025', 9),
#  ('CA', '94941', 9),
#  ('CA', '90068', 8),
#  ('CA', '94131', 8),
#  ('CA', '90069', 8),
#  ('CA', '90049', 8),
#  ('CA', '92064', 8),
#  ('CA', '90266', 7),
#  ('CA', '90803', 7),
#  ('CA', '93003', 7),
#  ('CA', '94602', 7),
#  ('CA', '94117', 7),
#  ('CA', '90278', 7),
#  ('CA', '94121', 7),
#  ('CA', '90291', 7),
#  ('CA', '90292', 7),
#  ('CA', '92103', 6),
#  ('CA', '92071', 6),
#  ('CA', '94901', 6),
#  ('CA', '94903', 6),
#  ('CA', '95008', 6),
#  ('CA', '94952', 6),
#  ('CA', '90274', 6),
#  ('CA', '95014', 6),
#  ('CA', '90277', 6),
#  ('CA', '94549', 6),
#  ('CA', '90036', 6),
#  ('CA', '94123', 6),
#  ('CA', '94061', 6),
#  ('CA', '92672', 6),
#  ('CA', '91301', 6),
#  ('CA', '90039', 6),
#  ('CA', '95762', 6),
#  ('CA', '95003', 5),
#  ('CA', '94597', 5),
#  ('CA', '90025', 5),
#  ('CA', '93940', 5),
#  ('CA', '92106', 5),
#  ('CA', '95818', 5),
#  ('CA', '94904', 5),
#  ('CA', '92122', 5),
#  ('CA', '92211', 5),
#  ('CA', '90405', 5),
#  ('CA', '94040', 5),
#  ('CA', '90210', 5),
#  ('CA', '93105', 5),
#  ('CA', '94118', 5),
#  ('CA', '93012', 5),
#  ('CA', '95476', 5),
#  ('CA', '94706', 5),
#  ('CA', '92009', 5),
#  ('CA', '94550', 5),
#  ('CA', '94510', 5),
#  ('CA', '90232', 5),
#  ('CA', '93023', 5),
#  ('CA', '92101', 5),
#  ('CA', '94109', 5),
#  ('CA', '91406', 5),
#  ('CO', '80304', 10),
#  ('CO', '80210', 9),
#  ('CO', '80526', 7),
#  ('CO', '80303', 7),
#  ('CO', '80220', 6),
#  ('CO', '80403', 6),
#  ('CO', '80205', 5),
#  ('CO', '80126', 5),
#  ('CO', '80206', 5),
#  ('CO', '80227', 5),
#  ('CO', '80401', 5),
#  ('CT', '6880', 8),
#  ('CT', '6824', 6),
#  ('CT', '6840', 6),
#  ('CT', '6614', 5),
#  ('CT', '6820', 5),
#  ('DC', '20009', 14),
#  ('DC', '20002', 8),
#  ('DC', '20007', 8),
#  ('DC', '20001', 7),
#  ('DC', '20016', 7),
#  ('DC', '20011', 6),
#  ('DC', '20005', 6),
#  ('DC', '20003', 5),
#  ('DE', '19958', 7),
#  ('FL', '32312', 6),
#  ('FL', '33647', 6),
#  ('FL', '33418', 6),
#  ('FL', '32751', 5),
#  ('FL', '32765', 5),
#  ('FL', '33156', 5),
#  ('GA', '30305', 7),
#  ('GA', '30004', 7),
#  ('GA', '30345', 6),
#  ('GA', '30316', 5),
#  ('GA', '30067', 5),
#  ('GA', '30308', 5),
#  ('GA', '30328', 5),
#  ('HI', '96734', 8),
#  ('ID', '83702', 9),
#  ('IL', '60614', 18),
#  ('IL', '60654', 11),
#  ('IL', '60640', 9),
#  ('IL', '60657', 9),
#  ('IL', '60613', 8),
#  ('IL', '60660', 7),
#  ('IL', '60610', 7),
#  ('IL', '60618', 6),
#  ('IL', '60647', 6),
#  ('IL', '60093', 5),
#  ('IL', '60642', 5),
#  ('IL', '60626', 5),
#  ('IN', '47401', 6),
#  ('KS', '66062', 6),
#  ('LA', '70115', 8),
#  ('LA', '70118', 6),
#  ('MA', '2127', 8),
#  ('MA', '2129', 6),
#  ('MA', '2143', 5),
#  ('MA', '2130', 5),
#  ('MA', '2116', 5),
#  ('MA', '2135', 5),
#  ('MA', '2472', 5),
#  ('MD', '20854', 8),
#  ('MD', '20817', 7),
#  ('MD', '20910', 7),
#  ('MD', '21286', 6),
#  ('MD', '20878', 6),
#  ('MD', '20895', 5),
#  ('MD', '21228', 5),
#  ('MD', '21230', 5),
#  ('MD', '20852', 5),
#  ('MI', '48103', 8),
#  ('MN', '55426', 6),
#  ('MO', '63139', 6),
#  ('MO', '63122', 5),
#  ('MT', '59715', 5),
#  ('N/A', 'N/A', 5713),
#  ('NC', '27701', 32),
#  ('NC', '27705', 26),
#  ('NC', '27516', 17),
#  ('NC', '27707', 17),
#  ('NC', '27517', 11),
#  ('NC', '27613', 11),
#  ('NC', '27615', 11),
#  ('NC', '27713', 10),
#  ('NC', '27514', 9),
#  ('NC', '27278', 9),
#  ('NC', '27539', 9),
#  ('NC', '27617', 9),
#  ('NC', '27614', 7),
#  ('NC', '27519', 7),
#  ('NC', '27608', 7),
#  ('NC', '27609', 7),
#  ('NC', '27513', 7),
#  ('NC', '28270', 6),
#  ('NC', '27587', 6),
#  ('NC', '27104', 6),
#  ('NC', '27410', 6),
#  ('NC', '27612', 6),
#  ('NC', '27603', 6),
#  ('NC', '28787', 6),
#  ('NC', '27607', 6),
#  ('NC', '28374', 6),
#  ('NC', '27502', 5),
#  ('NC', '27606', 5),
#  ('NC', '28226', 5),
#  ('NC', '28205', 5),
#  ('NJ', '7030', 8),
#  ('NJ', '7302', 7),
#  ('NJ', '8540', 5),
#  ('NM', '87111', 6),
#  ('NV', '89511', 5),
#  ('NY', '10003', 14),
#  ('NY', '10023', 13),
#  ('NY', '10024', 13),
#  ('NY', '11201', 12),
#  ('NY', '10025', 12),
#  ('NY', '10028', 11),
#  ('NY', '10016', 10),
#  ('NY', '10019', 9),
#  ('NY', '10011', 9),
#  ('NY', '10021', 8),
#  ('NY', '14850', 8),
#  ('NY', '11238', 8),
#  ('NY', '10014', 8),
#  ('NY', '11249', 7),
#  ('NY', '10128', 6),
#  ('NY', '10583', 6),
#  ('NY', '10012', 6),
#  ('NY', '10013', 6),
#  ('NY', '11217', 6),
#  ('NY', '11105', 5),
#  ('NY', '10075', 5),
#  ('NY', '10708', 5),
#  ('NY', '11222', 5),
#  ('NY', '10022', 5),
#  ('NY', '11209', 5),
#  ('NY', '11211', 5),
#  ('NY', '11215', 5),
#  ('OH', '43214', 8),
#  ('OH', '45040', 5),
#  ('OH', '43068', 5),
#  ('OH', '44149', 5),
#  ('OH', '43235', 5),
#  ('OH', '45243', 5),
#  ('OK', '73013', 5),
#  ('ON', 'M4E', 5),
#  ('OR', '97229', 8),
#  ('OR', '97212', 7),
#  ('OR', '97215', 5),
#  ('OR', '97405', 5),
#  ('OR', '97206', 5),
#  ('OR', '97702', 5),
#  ('PA', '19460', 6),
#  ('PA', '19147', 6),
#  ('PA', '19087', 6),
#  ('PA', '15237', 5),
#  ('PA', '15101', 5),
#  ('QC', 'J0X', 5),
#  ('SC', '29303', 14),
#  ('SC', '29464', 13),
#  ('SC', '29407', 5),
#  ('SC', '29707', 5),
#  ('SC', '29205', 5),
#  ('TN', '37205', 7),
#  ('TN', '37027', 6),
#  ('TN', '37067', 6),
#  ('TX', '78750', 8),
#  ('TX', '78745', 8),
#  ('TX', '77008', 8),
#  ('TX', '77007', 7),
#  ('TX', '78703', 7),
#  ('TX', '78704', 6),
#  ('TX', '77584', 6),
#  ('TX', '78757', 6),
#  ('TX', '78748', 5),
#  ('TX', '77381', 5),
#  ('TX', '77382', 5),
#  ('TX', '75023', 5),
#  ('TX', '78613', 5),
#  ('TX', '75025', 5),
#  ('TX', '77006', 5),
#  ('TX', '75248', 5),
#  ('TX', '75219', 5),
#  ('TX', '76712', 5),
#  ('UT', '84098', 6),
#  ('VA', '22201', 9),
#  ('VA', '20191', 9),
#  ('VA', '22314', 8),
#  ('VA', '22043', 7),
#  ('VA', '20147', 7),
#  ('VA', '22903', 7),
#  ('VA', '20120', 6),
#  ('VA', '22101', 6),
#  ('VA', '22304', 6),
#  ('VA', '23462', 5),
#  ('VA', '22301', 5),
#  ('VA', '22902', 5),
#  ('WA', '98103', 9),
#  ('WA', '98118', 7),
#  ('WA', '98122', 7),
#  ('WA', '98225', 7),
#  ('WA', '98102', 7),
#  ('WA', '98199', 6),
#  ('WA', '98074', 6),
#  ('WA', '98045', 6),
#  ('WA', '98052', 6),
#  ('WA', '98033', 6),
#  ('WA', '98115', 6),
#  ('WA', '98072', 5),
#  ('WA', '98106', 5),
#  ('WA', '98110', 5),
#  ('WI', '53213', 5)]

# %% [markdown]
# <mark>**Be sure to watch the next video before beginning Exercise 6, the next set of MySQL exercises</mark>,** **and feel free to practice any other queries you wish below!**
